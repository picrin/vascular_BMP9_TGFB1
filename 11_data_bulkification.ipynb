# %%
import anndata
import scanpy as sc
import numpy as np
import os

BATCH_LABELS = ("control", "TGFB1", "BMP9", "BMP9-TGFB1")
# Out:
# /usr/local/lib/python3.6/dist-packages/numba/errors.py:131: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)

# %%
combined_data = anndata.read("write/tgfb1-2.h5ad")

# %%
alk5_sig = ['SERPINE1', 'CTGF', 'SMAD7', 'COMP', 'NOX4', 'PMEPA4', 'RUNX1', 'PIGF', 'TAGLN', 'IL6', 'IL11', 'GJA4', 'LTBP1']
fibro_sig = ['S100A4', 'VIM', 'COL1A1', 'COL3A1', 'TSLP', 'CXCL14', 'SERPINH1']
smc_sig = ['ACTA2', 'CNN1', 'TAGLN', 'MYL9', 'MYH11', 'TAGLN2', 'MYOCDN', 'SMTN', 'SMAO', 'DES', 'LMOD1', 'P2X1', 'CRP1', 'CRP2', 'VCL', 'CALM1', 'MYLK', 'PP1', 'MYPT1', 'PPP1R12A']
alk1_sig = ['ID1', 'ID2', 'ID3', 'ID4', 'HAMP', 'PLAUR', 'SMAD6', 'HMGA2', 'IL8', 'EDN1', 'CXCL1', 'BMP6', 'HO1', 'JAG1', 'PTHLH', 'TLR4', 'RHOB', 'MAP3K5', 'ENG', 'COL5A1', 'HSP47', 'DDIT3', 'DNAJB1', 'HERPUD1', 'NEDD9', 'CRYAB', 'TPM1', 'LENG4', 'KPNA3', 'ANKRD15', 'SQLE', 'KDELR3', 'SCARA3', 'STAT1', 'IL1R1']
osteo_sig = ['RUNX2', 'OSX', 'ALPL', 'BSP', 'BGLAP', 'COL1A1', 'MSX2', 'SOX9', 'SOX5', 'DLX5', 'PIT1', 'PIT2', 'SOST']
angii_sig = ["AGTR1", "AGTR2", "MAS1"]
ca_handling_sig = ["ITPR1", "ITPR2", "ITPR3", "RYR1", "RYR2", "RYR3", "ATP2A1", "ATP2A2", "ATP2A3"]
apoptosis_sig = ['CASP1', 'CASP2', 'CASP3', 'CASP4', 'CASP5', 'CASP6', 'CASP7', 'CASP8', 'CASP9', 'CASP10', 'CASP11', 'CASP12', 'CASP12', 'CASP13', 'CASP14', 'TP53', 'BCL2']
SIGNATURES = {"alk5 signature": alk5_sig, "alk1 signature": alk1_sig, "fibro signature": fibro_sig,
              "smc signature": smc_sig, "osteo signature": osteo_sig,
              "ca2+ signature": ca_handling_sig, "apoptosis signature": apoptosis_sig}

# %%
combined_data
# Out:
# AnnData object with n_obs × n_vars = 6189 × 4606
#     obs: 'batch', 'cellular_barcode', 'n_counts', 'n_genes', 'percent_mito'
#     var: 'gene_names', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'genes_before_highly_variable', 'genes_original'
#     layers: 'ambiguous', 'spliced', 'unspliced'

# %%
def list_all_genes(anndata_matrix, cluster_no):
    log_fold_changes = np.array(anndata_matrix.uns['rank_genes_groups']['logfoldchanges'].tolist()).T[cluster_no].tolist()
    fold_changes = [i**2 for i in log_fold_changes]
    fdr = np.array(anndata_matrix.uns['rank_genes_groups']['pvals_adj'].tolist()).T[cluster_no].tolist()
    names = np.array(anndata_matrix.uns['rank_genes_groups']['names'].tolist()).T[cluster_no].tolist()
    genes = list(zip(names, fold_changes, fdr))
    return genes

# %%
def compare(case, control, number_of_genes, just_genes = False):
    print("\nComparing {} with {}, outputting {} genes".format(case, control, number_of_genes))
    sc.tl.rank_genes_groups(combined_data, "batch", n_genes=-1, groups = [case], reference = control, method="wilcoxon")
    all_genes = list_all_genes(combined_data, 0)
    print("Upregulated genes (gene, fold change, p-value):")
    for gene in all_genes[:number_of_genes]:
        if just_genes:
            print(gene[0])
        else:
            print(gene)
    print("Downregulated genes (gene, fold change, p-value):")
    for gene in all_genes[-number_of_genes:]:
        if just_genes:
            print(gene[0])
        else:
            print(gene)

# %%
def compare_signatures(case, control, genes_in_signature):
    
    print("\nComparing {} with {}, looking only at: {} genes".format(case, control, genes_in_signature))
    sc.tl.rank_genes_groups(combined_data, "batch", n_genes=-1, groups = [case], reference = control, method="wilcoxon")
    all_genes = list_all_genes(combined_data, 0)
    genes_to_stats = {i:(j, k) for i, j, k in all_genes}
    for gene in genes_in_signature:
        try:
            print(gene, genes_to_stats[gene])
        except KeyError:
            print("gene not present", gene)

# %% [markdown]
# You can change the number to get more/ less genes, and change just_genes=False to True if you want only genes names

# %% [markdown]
# # This lists top up/downregulated genes for bulkified data

# %%
for case, control in [["TGFB1", "control"], ["BMP9", "control"], ["BMP9-TGFB1", "control"], ["BMP9-TGFB1", "TGFB1"], ["BMP9-TGFB1", "BMP9"]]:
    compare(case, control, 50, just_genes=False)
# Out:
# Comparing TGFB1 with control, outputting 50 genes
# Upregulated genes (gene, fold change, p-value):
# ('HSPA5', 14.558324233549286, 0.0)
# ('TNFRSF12A', 18.774712899559972, 0.0)
# ('SH3PXD2A', 16.47223741565631, 0.0)
# ('MICAL2', 29.315320529595056, 0.0)
# ('PMEPA1', 48.415412207265035, 0.0)
# ('SERPINE2', 15.989242455169972, 0.0)
# ('PLOD2', 22.013663989528368, 0.0)
# ('VCAN', 10.917544985762163, 0.0)
# ('TPM1', 35.111374074733476, 0.0)
# ('GARS', 11.339302010060294, 0.0)
# ('COMP', 56.587511817963104, 0.0)
# ('SPARC', 13.697665533889051, 0.0)
# ('LTBP2', 13.002456704432973, 0.0)
# ('SLC3A2', 13.247545789618528, 0.0)
# ('TNFAIP6', 38.80230746032703, 0.0)
# ('PSAT1', 35.49693661593574, 0.0)
# ('BMPR2', 9.478653938615537, 0.0)
# ('SLC7A11', 28.97755034718307, 0.0)
# ('IARS', 10.478258450370959, 0.0)
# ('COL8A1', 30.912459351952748, 0.0)
# ('B4GALT1', 11.087886455427224, 0.0)
# ('UNC5B', 37.427357202454004, 0.0)
# ('ITGB1', 3.0227731240507296, 0.0)
# ('MTHFD2', 21.72917304767998, 0.0)
# ('PLXDC2', 46.529346958123824, 0.0)
# ('ACTN1', 8.887776503721398, 0.0)
# ('SCX', 80.57271616744401, 0.0)
# ('FGF2', 11.970836392563399, 0.0)
# ('GXYLT2', 12.903961084623234, 0.0)
# ('SKIL', 13.92906877759765, 0.0)
# ('TRIB3', 27.846632858450903, 0.0)
# ('HDGFL3', 15.85782495653126, 0.0)
# ('MT-ND3', 3.43354908298501, 0.0)
# ('RPS27', 2.856061915429237, 0.0)
# ('S100A6', 5.030486571559095, 0.0)
# ('RPL41', 2.011767393944183, 0.0)
#
# Comparing BMP9-TGFB1 with control, outputting 50 genes
# Upregulated genes (gene, fold change, p-value):
# ('HSPA5', 13.344634554305458, 0.0)
# ('PMEPA1', 52.40588023127407, 0.0)
# ('COMP', 69.84919437010922, 0.0)
# ('VCAN', 12.250467304871563, 0.0)
# ('TPM1', 36.05203791085137, 0.0)
# ('PLOD2', 23.139012396335602, 0.0)
# ('TNFRSF12A', 17.3101614089328, 0.0)
# ('GARS', 12.1529228415489, 0.0)
# ('SLC3A2', 14.489022649955189, 0.0)
# ('PSAT1', 38.74551848546639, 0.0)
# ('SLC7A11', 31.450608414621684, 0.0)
# ('BMPR2', 12.007906445146602, 0.0)
# ('SERPINE2', 13.916133829706268, 0.0)
# ('B4GALT1', 13.247075459011285, 0.0)
# ('SPARC', 13.730519153334399, 0.0)
# ('SH3PXD2A', 15.83243983124163, 0.0)
# ('MTHFD2', 23.155241094566236, 0.0)
# ('PLXDC2', 50.78060212912169, 0.0)
# ('UNC5B', 39.83974627175576, 0.0)
# ('HDGFL3', 19.40023358899998, 0.0)
# ('ID3', 39.593708204947916, 0.0)
# ('TNFAIP6', 36.900118995050434, 0.0)
# ('LTBP2', 12.097573101920943, 0.0)
# ('SLC7A5', 40.777904252769304, 0.0)
# ('SCX', 85.02449665120002, 0.0)
# ('GOLIM4', 11.200737298790045, 0.0)
# ('MICAL2', 24.785741273467465, 0.0)
# ('IARS', 9.901030093461486, 0.0)
# ('ITGB1', 3.1390852953477975, 0.0)
# ('SYNDIG1', 37.18375529688842, 0.0)
# ('TSPAN2', 115.01419838674428, 0.0)
# ('COL8A1', 27.78524971852312, 0.0)
# ('SEC61G', 4.665195602025051, 0.0)
# ('ASNS', 23.47828793003282, 0.0)
# ('EIF4EBP1', 14.44038378016836, 0.0)
# ('COL5A1', 8.036226242482428, 0.0)
# ('PDLIM4', 11.28889755426195, 0.0)
# ('FGF2', 10.581038138072074, 0.0)
# ('GXYLT2', 10.692145207946169, 0.0)
# ('RUNX1', 6.679952431717538, 0.0)
# ('ACTN1', 7.635298203408695, 0.0)
# ('VEGFA', 17.43731232398227, 0.0)
# ('FOXP1', 3.315775226324277, 0.0)
# ('ACTB', 2.3017750033750985, 0.0)
# ('TRIB3', 25.114031828845555, 0.0)
# ('ADAM12', 6.434007512212304, 0.0)
# ('SYNE1', 5.4961327748023905, 0.0)
# ('HECTD2', 16.181170218507987, 0.0)
# ('XBP1', 6.772975027263385, 0.0)
# ('ELN', 22.057657034751173, 0.0)
# Downregulated genes (gene, fold change, p-value):
# ('EFEMP1', 5.09021177938871, 0.0)
# ('CELF2', 7.871911373807961, 0.0)
# ('RPL30', 3.6785177006805867, 0.0)
# ('SOCS5', 8.311332357070626, 0.0)
# ('ADM', 52.26902532090412, 0.0)
# ('PTGIS', 5.7444035773451105, 0.0)
# ('B2M', 0.7511098851102957, 0.0)
# ('ITM2B', 1.574000043159586, 0.0)
# ('RPL30', 0.3977859386669138, 3.7157458315307575e-51)
# ('ADAMTSL1', 0.661070514147525, 1.4257435225729162e-51)
# ('ACVR2A', 1.728510084292921, 1.0657771261365308e-52)
# ('ANXA1', 0.6125026675957521, 1.6218419703552952e-53)
# ('EGR2', 0.7892518388232226, 1.1775795806052745e-53)
# ('WDFY2', 0.579244258575784, 7.201399229872556e-54)
# ('S100A10', 0.37332879533450125, 2.3543312818279124e-55)
# ('ZFP36L1', 0.4339419788591705, 4.984727597938793e-56)
# ('MSMO1', 1.417037128369941, 1.7509113999112976e-56)
# ('SLC9A1', 0.47741285836068315, 4.1728006954989837e-57)
# ('LOXL4', 2.4274385651935972, 9.90273980500139e-58)
# ('EMP2', 2.622429412488202, 8.268498702282753e-59)
# ('TIMP3', 0.8815149547602097, 1.3648823890949707e-60)
# ('EMP1', 0.441484759203977, 8.095422748473186e-61)
# ('RAI14', 0.3600926601898813, 1.1466727283351025e-62)
# ('PDGFC', 0.2792783775647969, 3.905276380718557e-63)
# ('UPP1', 4.804574091836514, 3.029543886870134e-66)
# ('DOCK10', 0.9073857843259283, 2.78364889650046e-67)
# ('EMP3', 0.5186017629445274, 1.9596535171547155e-69)
# ('MSC-AS1', 0.44714714775398434, 1.5371379707638417e-69)
# ('TXNIP', 1.9985773070341253, 8.286178462547155e-73)
# ('ARHGAP22', 1.4502722750208363, 3.92040711550852e-74)
# ('PRKG1', 0.9184926505351996, 1.124445488426563e-74)
# ('RALA', 0.5823717775755632, 1.974200294866948e-75)
# ('SH3BGRL3', 1.4193289845412096, 8.896737476238647e-76)
# ('FIBIN', 2.972895684529263, 1.0915544385272212e-86)
# ('GCLM', 0.7534485764371404, 1.600008180639024e-88)
# ('GALNT16', 2.0651294475783857, 3.510026855363693e-90)
# ('BNC2', 0.7091628681252224, 9.5739326721562e-92)
# ('ATP2B1', 0.7358696295253573, 3.263851069495287e-92)
# ('ZEB1', 0.8210341234191674, 9.340997725896369e-103)
# ('MIR503HG', 2.16722658167987, 1.258402957758588e-109)
# ('S100A16', 0.7987931324593411, 2.66926336927849e-114)
#
# Comparing BMP9-TGFB1 with BMP9, outputting 50 genes
# Upregulated genes (gene, fold change, p-value):
# ('RPL41', 2.7088216430019116, 0.0)
# ('HSPA5', 11.681915501254991, 0.0)
# ('RPS27', 3.1105477335000273, 0.0)
# ('RPL34', 2.3259958021613016, 0.0)
# ('SEC61G', 13.447686761705938, 0.0)
# ('PMEPA1', 32.94252855973264, 0.0)
# ('MT-ND3', 3.230449629344548, 0.0)
# ('GARS', 11.944721056356741, 0.0)
# ('PSAT1', 45.78483172599226, 0.0)
# ('PLOD2', 22.445046615780484, 0.0)
# ('TNFRSF12A', 13.143688141973144, 0.0)
# ('VCAN', 8.425804012348692, 0.0)
# ('MTHFD2', 22.60974040178212, 0.0)
# ('SH3PXD2A', 16.054684554265123, 0.0)
# ('SLC3A2', 11.325794105707473, 0.0)
# ('HDGFL3', 16.675551762355326, 0.0)
# ('DGKI', 16.166783705251873, 0.0)
# ('ACTB', 3.4859974196333496, 0.0)
# ('DTWD1', 8.373654941857467, 0.0)
# ('ANTXR2', 12.293751611738116, 0.0)
# ('PRRX1', 3.674805115640595, 0.0)
# ('BASP1', 5.906682561533728, 0.0)
# ('CEMIP', 38.57041984546436, 0.0)
# ('ACKR4', 36.526779190426396, 0.0)
# ('KCND2', 38.98393889452768, 0.0)
# ('CAV1', 15.906621246527322, 0.0)
# ('LGALS3', 4.002759455545458, 0.0)
# ('MITF', 25.7077110273176, 0.0)
# ('ARL6IP5', 12.7773099283595, 0.0)
# ('LMNA', 6.677988107540159, 0.0)
# ('REV3L', 13.471655188874365, 0.0)
# ('ANXA1', 9.504238890736417, 0.0)
# ('CCDC85B', 7.543299003592438, 0.0)
# ('AKR1C1', 18.173539061194788, 0.0)
# ('AKR1C2', 19.634946284695843, 0.0)
# ('CD44', 6.629943803163997, 0.0)
# ('PAM', 9.917003906503169, 0.0)
# ('PLPP3', 40.29400507981359, 0.0)
# ('NEAT1', 9.325556752505747, 0.0)

# %%
for case, control in [["TGFB1", "control"], ["BMP9", "control"], ["BMP9-TGFB1", "control"], ["BMP9-TGFB1", "TGFB1"], ["BMP9-TGFB1", "BMP9"]]:
    for signature in SIGNATURES.values():
        compare_signatures(case, control, signature)
# Out:
# Comparing TGFB1 with control, looking only at: ['SERPINE1', 'CTGF', 'SMAD7', 'COMP', 'NOX4', 'PMEPA4', 'RUNX1', 'PIGF', 'TAGLN', 'IL6', 'IL11', 'GJA4', 'LTBP1'] genes
# SERPINE1 (11.41685921746921, 0.0)
# CTGF (16.250030829361094, 0.0)
# SMAD7 (5.708034986512359, 6.318319454579118e-190)
# COMP (56.587511817963104, 0.0)
# NOX4 (32.22014947105913, 0.0)
# gene not present PMEPA4
# RUNX1 (6.732104852340456, 0.0)
# gene not present PIGF
# TAGLN (11.98987609559623, 9.199522787966049e-35)
# IL6 (1.5422193001081865, 1.404683831002279e-33)
# IL11 (78.730977769942, 0.0)
# gene not present GJA4
# LTBP1 (6.644761707866564, 0.0)
#
# Comparing TGFB1 with control, looking only at: ['ID1', 'ID2', 'ID3', 'ID4', 'HAMP', 'PLAUR', 'SMAD6', 'HMGA2', 'IL8', 'EDN1', 'CXCL1', 'BMP6', 'HO1', 'JAG1', 'PTHLH', 'TLR4', 'RHOB', 'MAP3K5', 'ENG', 'COL5A1', 'HSP47', 'DDIT3', 'DNAJB1', 'HERPUD1', 'NEDD9', 'CRYAB', 'TPM1', 'LENG4', 'KPNA3', 'ANKRD15', 'SQLE', 'KDELR3', 'SCARA3', 'STAT1', 'IL1R1'] genes
# ID1 (2.3645046010712036, 3.1782204703617144e-14)
# ID2 (3.9609251546545607, 2.279587544155932e-203)
# ID3 (6.813124996020235, 5.838762590133829e-46)
# ID4 (1.4159145906106119, 2.5411315827130328e-09)
# gene not present HAMP
# PLAUR (7.294124576161266, 4.4364924200943415e-253)
# SMAD6 (9.195149798415514, 2.52627064252227e-127)
# HMGA2 (2.656245973405248, 1.3422388029014037e-110)
# gene not present IL8
# EDN1 (0.3824732338699164, 0.7071884957987301)
# CXCL1 (0.8763654665256162, 0.4629654982009616)
# BMP6 (0.09461076953471448, 0.2567945670400983)
# gene not present HO1
# JAG1 (0.0059312995270489055, 0.974703485518689)
# PTHLH (1.452688829316017, 3.6379350346534546e-16)
# gene not present TLR4
# RHOB (0.0024183808391919914, 0.8623270167377959)
# MAP3K5 (2.7198396771371023, 0.0014406842807883262)
# ENG (0.7995533951276492, 2.8727300679653307e-75)
# COL5A1 (5.689055182132563, 0.0)
# gene not present HSP47
# DDIT3 (3.370329904391852, 1.2522745428369512e-66)
# gene not present DNAJB1
# gene not present HERPUD1
# NEDD9 (5.334267007338212, 3.895080863846022e-60)
# CRYAB (2.506946835253544, 5.69533202516138e-173)
# TPM1 (35.111374074733476, 0.0)
# gene not present LENG4
# gene not present KPNA3
# gene not present ANKRD15
# gene not present SQLE
# gene not present KDELR3
# SCARA3 (0.22461631277201377, 7.55726034253045e-14)
# STAT1 (0.023561570101159113, 0.0011171426921971152)
# IL1R1 (1.2611408385993315, 6.494565471255822e-89)
#
# Comparing TGFB1 with control, looking only at: ['S100A4', 'VIM', 'COL1A1', 'COL3A1', 'TSLP', 'CXCL14', 'SERPINH1'] genes
# S100A4 (12.781869797020647, 0.0)
# gene not present VIM
# COL1A1 (7.533846391612315, 0.0)
# COL3A1 (2.40257080607131, 2.1808633695903995e-235)
# TSLP (0.08748496398525063, 0.0002739800714755554)
# gene not present CXCL14
# SERPINH1 (6.666975254495867, 0.0)
#
# Comparing TGFB1 with control, looking only at: ['ACTA2', 'CNN1', 'TAGLN', 'MYL9', 'MYH11', 'TAGLN2', 'MYOCDN', 'SMTN', 'SMAO', 'DES', 'LMOD1', 'P2X1', 'CRP1', 'CRP2', 'VCL', 'CALM1', 'MYLK', 'PP1', 'MYPT1', 'PPP1R12A'] genes
# ACTA2 (0.01417245986199639, 0.6669666055588301)
# CNN1 (17.619280379789416, 3.3475945912655258e-34)
# TAGLN (11.98987609559623, 9.199522787966049e-35)
# MYL9 (0.07833672761101784, 3.298751378925753e-08)
# MYH11 (2.1383305364870466, 0.0005853888250425987)
# gene not present TAGLN2
# gene not present MYOCDN
# gene not present SMTN
# gene not present SMAO
# DES (1.5374436345755527, 1.2928809932254294e-05)
# LMOD1 (4.414396656510689, 5.446157844203041e-53)
# gene not present P2X1
# gene not present CRP1
# gene not present CRP2
# VCL (0.057659192884429666, 3.682743643502499e-07)
# gene not present CALM1
# MYLK (1.6213698278736501, 8.472578677374822e-70)
# gene not present PP1
# gene not present MYPT1
# gene not present PPP1R12A
#
# Comparing TGFB1 with control, looking only at: ['RUNX2', 'OSX', 'ALPL', 'BSP', 'BGLAP', 'COL1A1', 'MSX2', 'SOX9', 'SOX5', 'DLX5', 'PIT1', 'PIT2', 'SOST'] genes
# RUNX2 (5.737868285040349, 4.438060095383857e-148)
# gene not present OSX
# ALPL (2.0724755919218296, 0.00011238737238139833)
# gene not present BSP
# gene not present BGLAP
# COL1A1 (7.533846391612315, 0.0)
# MSX2 (0.04418467137844573, 0.9117506106644944)
# SOX9 (3.5891678049125773, 2.911103834095239e-19)
# SOX5 (11.159485797078617, 4.664884079881499e-168)
# DLX5 (7.476710155917544, 0.47111617535861544)
# gene not present PIT1
# gene not present PIT2
# SOST (440.837714822861, 0.8445080635887822)
#
# Comparing TGFB1 with control, looking only at: ['ITPR1', 'ITPR2', 'ITPR3', 'RYR1', 'RYR2', 'RYR3', 'ATP2A1', 'ATP2A2', 'ATP2A3'] genes
# ITPR1 (0.05400336748036616, 0.39458635722209434)
# ITPR2 (0.03435715279285123, 0.020335770912829527)
# ITPR3 (0.2248009569283207, 7.112964972376796e-06)
# gene not present RYR1
# RYR2 (0.49969909967149206, 0.3833161465461482)
# RYR3 (4.482895827116465, 1.9969017571250576e-13)
# gene not present ATP2A1
# ATP2A2 (1.4011116434579018e-05, 0.05427213435067541)
# ATP2A3 (3.088610335810259, 0.1514433635118361)
#
# Comparing TGFB1 with control, looking only at: ['CASP1', 'CASP2', 'CASP3', 'CASP4', 'CASP5', 'CASP6', 'CASP7', 'CASP8', 'CASP9', 'CASP10', 'CASP11', 'CASP12', 'CASP12', 'CASP13', 'CASP14', 'TP53', 'BCL2'] genes
# gene not present CASP1
# gene not present CASP2
# CASP3 (0.5260723880825289, 1.7473776488105732e-11)
# gene not present CASP4
# gene not present CASP5
# gene not present CASP6
# gene not present CASP7
# gene not present CASP8
# gene not present CASP9
# CASP10 (2.8114152210619636, 3.2419973328962724e-06)
# gene not present CASP11
# gene not present CASP12
# gene not present CASP12
# gene not present CASP13
# gene not present CASP14
# gene not present TP53
# BCL2 (0.09954398671652953, 0.0031992857922497225)
#
# Comparing BMP9 with control, looking only at: ['SERPINE1', 'CTGF', 'SMAD7', 'COMP', 'NOX4', 'PMEPA4', 'RUNX1', 'PIGF', 'TAGLN', 'IL6', 'IL11', 'GJA4', 'LTBP1'] genes
# SERPINE1 (0.8555444176097495, 8.729578166703044e-09)
# CTGF (0.11324267247960407, 0.0008437182927474127)
# SMAD7 (4.511961726529989, 6.022381198468638e-105)
# COMP (6.598218851221645, 3.4290535889297656e-23)
# NOX4 (0.02849234713988147, 0.7885622788061911)
# gene not present PMEPA4
# RUNX1 (0.24173989936537854, 2.348238992590353e-23)
# gene not present PIGF
# TAGLN (0.10996131423237276, 0.8967774386465639)
# IL6 (0.15006142027802127, 0.027255036698634227)
# IL11 (1.7034632822652043, 0.5774877277426174)
# gene not present GJA4
# LTBP1 (0.055347503567887424, 0.0027948391906076463)
#
# Comparing BMP9 with control, looking only at: ['ID1', 'ID2', 'ID3', 'ID4', 'HAMP', 'PLAUR', 'SMAD6', 'HMGA2', 'IL8', 'EDN1', 'CXCL1', 'BMP6', 'HO1', 'JAG1', 'PTHLH', 'TLR4', 'RHOB', 'MAP3K5', 'ENG', 'COL5A1', 'HSP47', 'DDIT3', 'DNAJB1', 'HERPUD1', 'NEDD9', 'CRYAB', 'TPM1', 'LENG4', 'KPNA3', 'ANKRD15', 'SQLE', 'KDELR3', 'SCARA3', 'STAT1', 'IL1R1'] genes
# ID1 (25.549089623920963, 0.0)
# ID2 (5.564119343637003, 0.0)
# ID3 (37.26306673536692, 0.0)
# ID4 (7.397079871516382, 8.529618492920977e-87)
# gene not present HAMP
# PLAUR (0.09657982981901014, 0.057400144685159436)
# SMAD6 (6.470374412201863, 3.8507017454564125e-266)
# HMGA2 (0.46510438136380117, 1.461339873231925e-24)
# gene not present IL8
# EDN1 (0.6238462571617589, 0.8320181100111608)
# CXCL1 (0.23884866556617457, 0.7322437637492857)
# BMP6 (0.12134401862523703, 0.7120946523400828)
# gene not present HO1
# JAG1 (0.039554416874143294, 0.24575847168765205)
# PTHLH (0.9664526727704015, 1.6237119787928022e-09)
# gene not present TLR4
# RHOB (0.11128652390767968, 0.4883857153041634)
# MAP3K5 (2.7166301595553364, 1.068409098221361e-12)
# ENG (1.2937254736389292, 6.440510847286233e-97)
# COL5A1 (2.2038645105118028e-05, 0.854640718749879)
# gene not present HSP47
# DDIT3 (0.06548241305822344, 0.3801578148672462)
# gene not present DNAJB1
# gene not present HERPUD1
# NEDD9 (0.09318212263405545, 0.275213114862899)
# CRYAB (1.3187408519292063, 6.7018814419898675e-112)
# TPM1 (2.255462500831541, 8.834413851969491e-33)
# gene not present LENG4
# gene not present KPNA3
# gene not present ANKRD15
# gene not present SQLE
# gene not present KDELR3
# SCARA3 (0.06132607824060088, 0.003367197442550362)
# STAT1 (0.09380580574486785, 8.322283253989683e-08)
# IL1R1 (0.4037329292486902, 2.5603868395045584e-35)
#
# Comparing BMP9 with control, looking only at: ['S100A4', 'VIM', 'COL1A1', 'COL3A1', 'TSLP', 'CXCL14', 'SERPINH1'] genes
# S100A4 (2.3706703128393656, 2.095608658165443e-208)
# gene not present VIM
# COL1A1 (0.033944986511770026, 0.000643673222818873)
# COL3A1 (0.01780587643482634, 0.032155207186461705)
# TSLP (3.3205855357062006, 1.1967513390235143e-14)
# gene not present CXCL14
# SERPINH1 (0.0038123984553566914, 0.6558213483780453)
#
# Comparing BMP9 with control, looking only at: ['ACTA2', 'CNN1', 'TAGLN', 'MYL9', 'MYH11', 'TAGLN2', 'MYOCDN', 'SMTN', 'SMAO', 'DES', 'LMOD1', 'P2X1', 'CRP1', 'CRP2', 'VCL', 'CALM1', 'MYLK', 'PP1', 'MYPT1', 'PPP1R12A'] genes
# ACTA2 (0.1284494400024414, 0.01806280552954199)
# CNN1 (2.488704416309929, 0.6775293253018126)
# TAGLN (0.10996131423237276, 0.8967774386465639)
# MYL9 (0.7274408983212197, 9.17970556220112e-39)
# MYH11 (0.002770129415990974, 0.8189767253852552)
# gene not present TAGLN2
# gene not present MYOCDN
# gene not present SMTN
# gene not present SMAO
# DES (0.11698441128221848, 0.11365369177004064)
# LMOD1 (2.041162826686346, 2.6123784637775133e-25)
# gene not present P2X1
# gene not present CRP1
# gene not present CRP2
# VCL (0.010337998806521365, 0.04013561057508489)
# gene not present CALM1
# MYLK (0.002051391358159016, 0.6953368700158771)
# gene not present PP1
# gene not present MYPT1
# gene not present PPP1R12A
#
# Comparing BMP9 with control, looking only at: ['RUNX2', 'OSX', 'ALPL', 'BSP', 'BGLAP', 'COL1A1', 'MSX2', 'SOX9', 'SOX5', 'DLX5', 'PIT1', 'PIT2', 'SOST'] genes
# RUNX2 (0.4521573470311182, 3.4498941955361453e-10)
# gene not present OSX
# ALPL (0.2780321528131289, 0.19181069156949432)
# gene not present BSP
# gene not present BGLAP
# COL1A1 (0.033944986511770026, 0.000643673222818873)
# MSX2 (0.4343282667327095, 0.11560187943019333)
# SOX9 (0.8180574031487744, 0.0005316803120287098)
# SOX5 (0.31949669074151643, 5.668704098742115e-10)
# DLX5 (15.076492116969348, 0.21502110554287054)
# gene not present PIT1
# gene not present PIT2
# SOST (456.72536008220413, 0.8878921486685545)
#
# Comparing BMP9 with control, looking only at: ['ITPR1', 'ITPR2', 'ITPR3', 'RYR1', 'RYR2', 'RYR3', 'ATP2A1', 'ATP2A2', 'ATP2A3'] genes
# ITPR1 (0.0027381059207076813, 0.927786031052328)
# ITPR2 (0.0852699673609516, 0.011595535361761439)
# ITPR3 (0.29008690780301905, 2.0186035340409637e-06)
# gene not present RYR1
# RYR2 (0.20576276482345524, 0.5827573821602792)
# RYR3 (0.03015849780044122, 0.700661061538632)
# gene not present ATP2A1
# ATP2A2 (0.0022490375195935997, 0.4506201779272832)
# ATP2A3 (0.7724838447946389, 0.6798539289789941)
#
# Comparing BMP9 with control, looking only at: ['CASP1', 'CASP2', 'CASP3', 'CASP4', 'CASP5', 'CASP6', 'CASP7', 'CASP8', 'CASP9', 'CASP10', 'CASP11', 'CASP12', 'CASP12', 'CASP13', 'CASP14', 'TP53', 'BCL2'] genes
# gene not present CASP1
# gene not present CASP2
# CASP3 (0.00021371456942692948, 0.9670601958684981)
# gene not present CASP4
# gene not present CASP5
# gene not present CASP6
# gene not present CASP7
# gene not present CASP8
# gene not present CASP9
# CASP10 (0.006247909069480251, 0.6865352325148475)
# gene not present CASP11
# gene not present CASP12
# gene not present CASP12
# gene not present CASP13
# gene not present CASP14
# gene not present TP53
# BCL2 (0.5341485780045083, 2.660583276529345e-06)
#
# Comparing BMP9-TGFB1 with control, looking only at: ['SERPINE1', 'CTGF', 'SMAD7', 'COMP', 'NOX4', 'PMEPA4', 'RUNX1', 'PIGF', 'TAGLN', 'IL6', 'IL11', 'GJA4', 'LTBP1'] genes
# SERPINE1 (9.74731410388108, 3.9861032942169605e-282)
# CTGF (11.809509807048016, 6.58831959826135e-281)
# SMAD7 (10.731254519811273, 0.0)
# COMP (69.84919437010922, 0.0)
# NOX4 (26.4016901723719, 6.121218144169369e-286)
# gene not present PMEPA4
# RUNX1 (6.679952431717538, 0.0)
# gene not present PIGF
# TAGLN (9.739504363112758, 6.086077441259436e-27)
# IL6 (4.2976678667074, 1.3081835674932983e-93)
# IL11 (90.92657054232495, 0.0)
# gene not present GJA4
# LTBP1 (6.70403205516601, 0.0)
#
# Comparing BMP9-TGFB1 with control, looking only at: ['ID1', 'ID2', 'ID3', 'ID4', 'HAMP', 'PLAUR', 'SMAD6', 'HMGA2', 'IL8', 'EDN1', 'CXCL1', 'BMP6', 'HO1', 'JAG1', 'PTHLH', 'TLR4', 'RHOB', 'MAP3K5', 'ENG', 'COL5A1', 'HSP47', 'DDIT3', 'DNAJB1', 'HERPUD1', 'NEDD9', 'CRYAB', 'TPM1', 'LENG4', 'KPNA3', 'ANKRD15', 'SQLE', 'KDELR3', 'SCARA3', 'STAT1', 'IL1R1'] genes
# ID1 (7.323312639593723, 1.6997527636524997e-170)
# ID2 (0.04311403840468153, 8.64880484193772e-06)
# ID3 (39.593708204947916, 0.0)
# ID4 (10.26064974322486, 2.207038322627454e-163)
# gene not present HAMP
# PLAUR (9.946486088227232, 0.0)
# SMAD6 (0.005357324135113695, 0.621776260545078)
# HMGA2 (5.38469542900657, 3.458881203936025e-176)
# gene not present IL8
# EDN1 (1.6776838304389372, 0.1110529262593208)
# CXCL1 (0.006980914779362246, 0.8943781795849433)
# BMP6 (2.4029396353600987, 1.5387566510775156e-09)
# gene not present HO1
# JAG1 (1.8516083352523225, 2.4481068043602466e-49)
# PTHLH (3.5636645350883214, 6.255941242322738e-45)
# gene not present TLR4
# RHOB (0.06574022086068965, 0.7511717992593209)
# MAP3K5 (4.858151982008167, 0.00022133125303685518)
# ENG (2.2472656932804966, 1.5019820251022062e-192)
# COL5A1 (8.036226242482428, 0.0)
# gene not present HSP47
# DDIT3 (2.9316171577266346, 2.075402012406566e-62)
# gene not present DNAJB1
# gene not present HERPUD1
# NEDD9 (4.302733558834234, 6.518576100827194e-52)
# CRYAB (0.3106827864257866, 1.6363247454928802e-18)
# TPM1 (36.05203791085137, 0.0)
# gene not present LENG4
# gene not present KPNA3
# gene not present ANKRD15
# gene not present SQLE
# gene not present KDELR3
# SCARA3 (0.09328997599035294, 8.581748334605968e-05)
# STAT1 (0.15382415415752249, 5.042792787725279e-16)
# IL1R1 (0.6975702107618851, 8.40860016355971e-59)
#
# Comparing BMP9-TGFB1 with control, looking only at: ['S100A4', 'VIM', 'COL1A1', 'COL3A1', 'TSLP', 'CXCL14', 'SERPINH1'] genes
# S100A4 (11.860909413145748, 0.0)
# gene not present VIM
# COL1A1 (6.685937143650392, 0.0)
# COL3A1 (3.2826883661073225, 7.560997739274493e-276)
# TSLP (0.5567133413552625, 0.00012502747492607315)
# gene not present CXCL14
# SERPINH1 (6.350850522974326, 0.0)
#
# Comparing BMP9-TGFB1 with control, looking only at: ['ACTA2', 'CNN1', 'TAGLN', 'MYL9', 'MYH11', 'TAGLN2', 'MYOCDN', 'SMTN', 'SMAO', 'DES', 'LMOD1', 'P2X1', 'CRP1', 'CRP2', 'VCL', 'CALM1', 'MYLK', 'PP1', 'MYPT1', 'PPP1R12A'] genes
# ACTA2 (0.036014524237604206, 0.8101778880239958)
# CNN1 (22.857975991694047, 1.047170329493317e-80)
# TAGLN (9.739504363112758, 6.086077441259436e-27)
# MYL9 (0.01901177718460212, 0.0028403744825403823)
# MYH11 (3.118977168231382, 0.00039689316179480005)
# gene not present TAGLN2
# gene not present MYOCDN
# gene not present SMTN
# gene not present SMAO
# DES (0.9520040228683371, 0.000949945653818371)
# LMOD1 (4.977912901501952, 6.962533597072728e-56)
# gene not present P2X1
# gene not present CRP1
# gene not present CRP2
# VCL (0.19232769300487806, 3.663580990746385e-23)
# gene not present CALM1
# MYLK (0.891651601643165, 3.961822146819338e-34)
# gene not present PP1
# gene not present MYPT1
# gene not present PPP1R12A
#
# Comparing BMP9-TGFB1 with control, looking only at: ['RUNX2', 'OSX', 'ALPL', 'BSP', 'BGLAP', 'COL1A1', 'MSX2', 'SOX9', 'SOX5', 'DLX5', 'PIT1', 'PIT2', 'SOST'] genes
# RUNX2 (9.726349345888593, 3.733128980448242e-255)
# gene not present OSX
# ALPL (1.3209030469074747, 0.0018912027876751818)
# gene not present BSP
# gene not present BGLAP
# COL1A1 (6.685937143650392, 0.0)
# MSX2 (1.1939203555230051, 3.57539159899309e-05)
# SOX9 (2.6265421426515445, 1.667983146820637e-11)
# SOX5 (2.1330790589709068, 1.0422744268949285e-73)
# DLX5 (31.009058340649972, 1.865860708917255e-06)
# gene not present PIT1
# gene not present PIT2
# SOST (681.8316376494513, 0.006297427315104292)
#
# Comparing BMP9-TGFB1 with control, looking only at: ['ITPR1', 'ITPR2', 'ITPR3', 'RYR1', 'RYR2', 'RYR3', 'ATP2A1', 'ATP2A2', 'ATP2A3'] genes
# ITPR1 (0.0006335919256138557, 0.7029818656084595)
# ITPR2 (0.020307124346965688, 0.6302664627968663)
# ITPR3 (1.4523885535800787, 7.787153135803372e-20)
# gene not present RYR1
# RYR2 (0.385183626597442, 0.24185885100914495)
# RYR3 (3.3704817879175266, 5.607714764087518e-10)
# gene not present ATP2A1
# ATP2A2 (0.00016807915670117527, 0.04802104838587048)
# ATP2A3 (2.4523880615748226, 0.235051487818438)
#
# Comparing BMP9-TGFB1 with control, looking only at: ['CASP1', 'CASP2', 'CASP3', 'CASP4', 'CASP5', 'CASP6', 'CASP7', 'CASP8', 'CASP9', 'CASP10', 'CASP11', 'CASP12', 'CASP12', 'CASP13', 'CASP14', 'TP53', 'BCL2'] genes
# gene not present CASP1
# gene not present CASP2
# CASP3 (0.0763617080794754, 0.006140519489734282)
# gene not present CASP4
# gene not present CASP5
# gene not present CASP6
# gene not present CASP7
# gene not present CASP8
# gene not present CASP9
# CASP10 (3.902680741730876, 9.972283759337669e-07)
# gene not present CASP11
# gene not present CASP12
# gene not present CASP12
# gene not present CASP13
# gene not present CASP14
# gene not present TP53
# BCL2 (0.4652362577223954, 7.993493855228837e-08)
#
# Comparing BMP9-TGFB1 with TGFB1, looking only at: ['SERPINE1', 'CTGF', 'SMAD7', 'COMP', 'NOX4', 'PMEPA4', 'RUNX1', 'PIGF', 'TAGLN', 'IL6', 'IL11', 'GJA4', 'LTBP1'] genes
# SERPINE1 (0.06595410565536497, 1.5311866119711724e-05)
# CTGF (0.35359192901614733, 3.044141260602299e-18)
# SMAD7 (0.7862541802106229, 6.971260971049214e-92)
# COMP (0.6974188810883994, 5.938551771586258e-78)
# NOX4 (0.2894675245353575, 3.58705926251242e-24)
# gene not present PMEPA4
# RUNX1 (0.00010139598755328025, 0.7032875304153879)
# gene not present PIGF
# TAGLN (0.11684233968384561, 0.07949438462591822)
# IL6 (0.6909279286478665, 3.379175064558955e-23)
# IL11 (0.4388993317161436, 5.137488994339174e-24)
# gene not present GJA4
# LTBP1 (0.00013158765571882978, 0.7601103553500455)
#
# Comparing BMP9-TGFB1 with TGFB1, looking only at: ['ID1', 'ID2', 'ID3', 'ID4', 'HAMP', 'PLAUR', 'SMAD6', 'HMGA2', 'IL8', 'EDN1', 'CXCL1', 'BMP6', 'HO1', 'JAG1', 'PTHLH', 'TLR4', 'RHOB', 'MAP3K5', 'ENG', 'COL5A1', 'HSP47', 'DDIT3', 'DNAJB1', 'HERPUD1', 'NEDD9', 'CRYAB', 'TPM1', 'LENG4', 'KPNA3', 'ANKRD15', 'SQLE', 'KDELR3', 'SCARA3', 'STAT1', 'IL1R1'] genes
# ID1 (18.010321446165335, 7.486722590854984e-265)
# ID2 (4.830528853636679, 4.199182169128341e-261)
# ID3 (13.558278708798355, 0.0)
# ID4 (4.053388176726912, 6.2352424087683504e-117)
# gene not present HAMP
# PLAUR (0.2052463791615402, 3.998389815759689e-19)
# SMAD6 (9.644405577455984, 2.520757743864438e-150)
# HMGA2 (0.47706014249696693, 4.872332256564363e-10)
# gene not present IL8
# EDN1 (0.4580719728867422, 0.3212767479964652)
# CXCL1 (1.0397794405546392, 0.7651165347136266)
# BMP6 (3.451163082716505, 5.588628349414534e-14)
# gene not present HO1
# JAG1 (1.6479453444134293, 4.3280514457290375e-51)
# PTHLH (0.46579494749011374, 2.659849711858277e-10)
# gene not present TLR4
# RHOB (0.09337647115604941, 0.8114295469974059)
# MAP3K5 (0.30794528890432105, 0.8347209307993191)
# ENG (0.36591706497177157, 2.5767996772505876e-50)
# COL5A1 (0.2021850059468342, 1.0858052812460564e-53)
# gene not present HSP47
# DDIT3 (0.01528914365143269, 0.25980823167221234)
# gene not present DNAJB1
# gene not present HERPUD1
# NEDD9 (0.05536609210935595, 0.06338198195163544)
# CRYAB (4.582695940845042, 6.919435472472242e-201)
# TPM1 (0.006217262750312591, 0.06807459125567897)
# gene not present LENG4
# gene not present KPNA3
# gene not present ANKRD15
# gene not present SQLE
# gene not present KDELR3
# SCARA3 (0.6074193775862256, 2.699638105294724e-31)
# STAT1 (0.05698075725623952, 1.748533873828372e-05)
# IL1R1 (0.08282802466894523, 1.6514554523462438e-05)
#
# Comparing BMP9-TGFB1 with TGFB1, looking only at: ['S100A4', 'VIM', 'COL1A1', 'COL3A1', 'TSLP', 'CXCL14', 'SERPINH1'] genes
# S100A4 (0.01721530532030613, 0.02196607509584709)
# gene not present VIM
# COL1A1 (0.025302477974005422, 9.448542937142808e-07)
# COL3A1 (0.06853730041231998, 2.539087056995293e-17)
# TSLP (1.0855780475475427, 6.292751831542822e-16)
# gene not present CXCL14
# SERPINH1 (0.0038389405694583822, 0.0743154575718782)
#
# Comparing BMP9-TGFB1 with TGFB1, looking only at: ['ACTA2', 'CNN1', 'TAGLN', 'MYL9', 'MYH11', 'TAGLN2', 'MYOCDN', 'SMTN', 'SMAO', 'DES', 'LMOD1', 'P2X1', 'CRP1', 'CRP2', 'VCL', 'CALM1', 'MYLK', 'PP1', 'MYPT1', 'PPP1R12A'] genes
# ACTA2 (0.005002276649977377, 0.9574246809301504)
# CNN1 (0.34043590408674973, 9.049217484076303e-11)
# TAGLN (0.11684233968384561, 0.07949438462591822)
# MYL9 (0.17453192089583158, 1.0333862094757386e-16)
# MYH11 (0.0922697707045792, 0.9980425411539016)
# gene not present TAGLN2
# gene not present MYOCDN
# gene not present SMTN
# gene not present SMAO
# DES (0.06981749971379259, 0.4114024498094406)
# LMOD1 (0.01692002320558239, 0.864970580553103)
# gene not present P2X1
# gene not present CRP1
# gene not present CRP2
# VCL (0.03937387422355698, 5.651915911472699e-06)
# gene not present CALM1
# MYLK (0.10827857337234548, 4.1967662076796004e-08)
# gene not present PP1
# gene not present MYPT1
# gene not present PPP1R12A
#
# Comparing BMP9-TGFB1 with TGFB1, looking only at: ['RUNX2', 'OSX', 'ALPL', 'BSP', 'BGLAP', 'COL1A1', 'MSX2', 'SOX9', 'SOX5', 'DLX5', 'PIT1', 'PIT2', 'SOST'] genes
# RUNX2 (0.52319890358946, 1.873407422566998e-33)
# gene not present OSX
# ALPL (0.08427639810035803, 0.61123528999209)
# gene not present BSP
# gene not present BGLAP
# COL1A1 (0.025302477974005422, 9.448542937142808e-07)
# MSX2 (0.7787446953062158, 6.862637998773947e-05)
# SOX9 (0.07499321524336722, 0.045624384927847844)
# SOX5 (3.5346828189204302, 7.588474945793414e-23)
# DLX5 (8.032806680483247, 5.342198635554888e-05)
# gene not present PIT1
# gene not present PIT2
# SOST (26.17110129249545, 0.014846960999478303)
#
# Comparing BMP9-TGFB1 with TGFB1, looking only at: ['ITPR1', 'ITPR2', 'ITPR3', 'RYR1', 'RYR2', 'RYR3', 'ATP2A1', 'ATP2A2', 'ATP2A3'] genes
# ITPR1 (0.06633587164232324, 0.3396046344853759)
# ITPR2 (0.10749209995628917, 0.005934116518480484)
# ITPR3 (0.5343888948638131, 1.1527919637043687e-05)
# gene not present RYR1
# RYR2 (0.0074412050731729185, 0.9009488123995366)
# RYR3 (0.0791846657396178, 0.3341973012516048)
# gene not present ATP2A1
# ATP2A2 (8.503318986757911e-05, 0.9549706341573383)
# ATP2A3 (0.03664702045146928, 0.9595372787748919)
#
# Comparing BMP9-TGFB1 with TGFB1, looking only at: ['CASP1', 'CASP2', 'CASP3', 'CASP4', 'CASP5', 'CASP6', 'CASP7', 'CASP8', 'CASP9', 'CASP10', 'CASP11', 'CASP12', 'CASP12', 'CASP13', 'CASP14', 'TP53', 'BCL2'] genes
# gene not present CASP1
# gene not present CASP2
# CASP3 (0.20157608575218067, 3.3358901510430564e-05)
# gene not present CASP4
# gene not present CASP5
# gene not present CASP6
# gene not present CASP7
# gene not present CASP8
# gene not present CASP9
# CASP10 (0.08927721409606537, 0.965074010923594)
# gene not present CASP11
# gene not present CASP12
# gene not present CASP12
# gene not present CASP13
# gene not present CASP14
# gene not present TP53
# BCL2 (0.13437821581529708, 0.03957722343526609)
#
# Comparing BMP9-TGFB1 with BMP9, looking only at: ['SERPINE1', 'CTGF', 'SMAD7', 'COMP', 'NOX4', 'PMEPA4', 'RUNX1', 'PIGF', 'TAGLN', 'IL6', 'IL11', 'GJA4', 'LTBP1'] genes
# SERPINE1 (16.378412999422153, 0.0)
# CTGF (14.235620768977242, 3.0708437978960087e-267)
# SMAD7 (1.3264623617544657, 3.0960594693199602e-108)
# COMP (33.51116881008784, 0.0)
# NOX4 (24.695542274736226, 3.8445351525935116e-246)
# gene not present PMEPA4
# RUNX1 (4.380188653333846, 0.0)
# gene not present PIGF
# TAGLN (11.919218646770787, 4.749708228822015e-25)
# IL6 (2.8415987552953084, 9.394139773835671e-64)
# IL11 (67.73907741287621, 0.0)
# gene not present GJA4
# LTBP1 (7.9776593079173495, 0.0)
#
# Comparing BMP9-TGFB1 with BMP9, looking only at: ['ID1', 'ID2', 'ID3', 'ID4', 'HAMP', 'PLAUR', 'SMAD6', 'HMGA2', 'IL8', 'EDN1', 'CXCL1', 'BMP6', 'HO1', 'JAG1', 'PTHLH', 'TLR4', 'RHOB', 'MAP3K5', 'ENG', 'COL5A1', 'HSP47', 'DDIT3', 'DNAJB1', 'HERPUD1', 'NEDD9', 'CRYAB', 'TPM1', 'LENG4', 'KPNA3', 'ANKRD15', 'SQLE', 'KDELR3', 'SCARA3', 'STAT1', 'IL1R1'] genes
# ID1 (5.5152115471437355, 9.742484895199633e-261)
# ID2 (4.627658603945747, 0.0)
# ID3 (0.03534585774573973, 1.6075154781844264e-05)
# ID4 (0.23374098628651385, 2.77796804167057e-10)
# gene not present HAMP
# PLAUR (12.003300117217407, 1.9341449895902427e-297)
# SMAD6 (6.103366678225086, 5.738478620991118e-276)
# HMGA2 (9.014889194296302, 1.1161999844589539e-232)
# gene not present IL8
# EDN1 (0.2554442845903395, 0.24717549998930136)
# CXCL1 (0.32749681413589826, 0.750552672715504)
# BMP6 (1.4443166227356983, 5.159635044434905e-07)
# gene not present HO1
# JAG1 (2.4324179620194286, 9.353042390518133e-53)
# PTHLH (0.8184529371317559, 8.633591009664788e-13)
# gene not present TLR4
# RHOB (0.0059594942020604336, 0.4747271621185835)
# MAP3K5 (14.840539876970297, 4.56181046682515e-28)
# ENG (0.130803519914938, 1.0532922124611459e-18)
# COL5A1 (8.062865579086974, 0.0)
# gene not present HSP47
# DDIT3 (3.8733855123723657, 6.007058550779994e-66)
# gene not present DNAJB1
# gene not present HERPUD1
# NEDD9 (3.1295227260636835, 2.6383970403296e-38)
# CRYAB (0.34925171653043563, 4.887406500413816e-28)
# TPM1 (20.27264417090032, 0.0)
# gene not present LENG4
# gene not present KPNA3
# gene not present ANKRD15
# gene not present SQLE
# gene not present KDELR3
# SCARA3 (0.0033400453562395516, 0.6190073800757822)
# STAT1 (0.4878764893155676, 7.023825616572523e-37)
# IL1R1 (2.1626833197996262, 1.385138652879592e-153)
#
# Comparing BMP9-TGFB1 with BMP9, looking only at: ['S100A4', 'VIM', 'COL1A1', 'COL3A1', 'TSLP', 'CXCL14', 'SERPINH1'] genes
# S100A4 (3.6262398942771057, 5.83570107582427e-196)
# gene not present VIM
# COL1A1 (7.672676674179058, 0.0)
# COL3A1 (2.8169610670286147, 1.137333530472044e-200)
# TSLP (1.158024032546919, 7.611440118674571e-07)
# gene not present CXCL14
# SERPINH1 (6.6658672054705335, 0.0)
#
# Comparing BMP9-TGFB1 with BMP9, looking only at: ['ACTA2', 'CNN1', 'TAGLN', 'MYL9', 'MYH11', 'TAGLN2', 'MYOCDN', 'SMTN', 'SMAO', 'DES', 'LMOD1', 'P2X1', 'CRP1', 'CRP2', 'VCL', 'CALM1', 'MYLK', 'PP1', 'MYPT1', 'PPP1R12A'] genes
# ACTA2 (0.3004941067067648, 0.0045825121306914875)
# CNN1 (40.4313409343049, 2.1706836296278591e-75)
# TAGLN (11.919218646770787, 4.749708228822015e-25)
# MYL9 (0.5112510446289242, 9.854007676707957e-25)
# MYH11 (3.307649583621597, 0.00020162736386085883)
# gene not present TAGLN2
# gene not present MYOCDN
# gene not present SMTN
# gene not present SMAO
# DES (1.7364301288087205, 3.420711840561432e-07)
# LMOD1 (0.6438953938152601, 3.479431808650386e-05)
# gene not present P2X1
# gene not present CRP1
# gene not present CRP2
# VCL (0.11348534230365104, 9.048509934151024e-12)
# gene not present CALM1
# MYLK (0.8081663650160777, 1.1036770292710024e-27)
# gene not present PP1
# gene not present MYPT1
# gene not present PPP1R12A
#
# Comparing BMP9-TGFB1 with BMP9, looking only at: ['RUNX2', 'OSX', 'ALPL', 'BSP', 'BGLAP', 'COL1A1', 'MSX2', 'SOX9', 'SOX5', 'DLX5', 'PIT1', 'PIT2', 'SOST'] genes
# RUNX2 (5.984301015304538, 4.513398582223894e-175)
# gene not present OSX
# ALPL (0.3869062186722658, 0.25444335116476835)
# gene not present BSP
# gene not present BGLAP
# COL1A1 (7.672676674179058, 0.0)
# MSX2 (0.18803563990732997, 0.055698401929667046)
# SOX9 (0.5129363697322766, 0.010621676735800676)
# SOX5 (4.103650188290203, 7.44467636636535e-98)
# DLX5 (2.8416919976043573, 0.0035499578291711405)
# gene not present PIT1
# gene not present PIT2
# SOST (22.47492150090693, 0.01880305448178664)
#
# Comparing BMP9-TGFB1 with BMP9, looking only at: ['ITPR1', 'ITPR2', 'ITPR3', 'RYR1', 'RYR2', 'RYR3', 'ATP2A1', 'ATP2A2', 'ATP2A3'] genes
# ITPR1 (0.0007374331122878552, 0.8835454709434446)
# ITPR2 (0.022352401284245538, 0.029077567954893763)
# ITPR3 (3.0406569117349704, 4.367456169490372e-43)
# gene not present RYR1
# RYR2 (0.02789595682941215, 0.7280734458710739)
# RYR3 (2.7629923735620565, 1.198656272124279e-07)
# gene not present ATP2A1
# ATP2A2 (0.0011874567304795414, 0.4363829679493028)
# ATP2A3 (0.4721058273344312, 0.5948894962978888)
#
# Comparing BMP9-TGFB1 with BMP9, looking only at: ['CASP1', 'CASP2', 'CASP3', 'CASP4', 'CASP5', 'CASP6', 'CASP7', 'CASP8', 'CASP9', 'CASP10', 'CASP11', 'CASP12', 'CASP12', 'CASP13', 'CASP14', 'TP53', 'BCL2'] genes
# gene not present CASP1
# gene not present CASP2
# CASP3 (0.08465497222324903, 0.007030891931534747)
# gene not present CASP4
# gene not present CASP5
# gene not present CASP6
# gene not present CASP7
# gene not present CASP8
# gene not present CASP9
# CASP10 (4.221233226710183, 1.6399983975843453e-07)
# gene not present CASP11
# gene not present CASP12
# gene not present CASP12
# gene not present CASP13
# gene not present CASP14
# gene not present TP53
# BCL2 (0.002378751567951254, 0.9368428820913348)
