# %% [markdown]
# # TGFB1 Part 1 - Importing the data
#
# In this notebook, we take the data from the matrix, gene and cell files and create an AnnData matrix we can use for future analyses.

# %% [markdown]
# # Before this notebook was executed, we have aligned our data using these steps:
#
# https://docs.google.com/document/d/1HI_tOIbaw0x1jzzINAAwBlj__7eSiFfDaIO43Hux2D4/edit?usp=sharing

# %%
from collections import defaultdict

import numpy as np
import pandas
import scanpy
import scanpy as sc
import anndata
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd
import scanpy as sc

sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/numba/errors.py:105: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)
# scanpy==1.4 anndata==0.6.19 numpy==1.17.0 scipy==1.2.1 pandas==0.25.0 scikit-learn==0.20.3 statsmodels==0.9.0 python-igraph==0.7.1 louvain==0.6.1

# %% [markdown]
# # Loading genes
#
# Create a function to load all the gene data from the dimension 1 file, creating a list mapping row IDs to genes.
#
# The gene file is simply a list of genes with each line containing the gene name for the appropriate row in the count matrix.

# %%
def load_genes(batch, variant):
    genes_result = []
    genes_path = "source/{}.{}.genes.tsv".format(batch, variant)

    with open(genes_path, "r") as genes:
        for gene in genes:
            gene = gene.strip()
            genes_result.append(gene)
    
    return genes_result

# %%
genes1 = set(load_genes("control", "all"))
genes1
# Out:
# {'AL391987.3',
#  'SLC25A53',
#  'SOGA1',
#  'RIPOR2',
#  'AC018946.1',
#  'SLC16A3',
#  'PRAMEF4',
#  'AC068389.4',
#  'HSP90AB1',
#  'POLR3D',
#  'ZNF236-DT',
#  'LINC02137',
#  'SEC23B',
#  'Z98200.1',
#  'TSPO',
#  'LIPC-AS1',
#  'ACTR6',
#  'NDUFB3',
#  'ETNK2',
#  'AL391261.2',
#  'CDK4',
#  'TMEM98',
#  'MTFR2',
#  'AC125793.1',
#  'AL157359.2',
#  'NCKIPSD',
#  'INSIG1',
#  'TRPM2',
#  'JRK',
#  'AC016831.5',
#  'CMTM8',
#  'PDC',
#  'PAX9',
#  'EPHA5-AS1',
#  'LINC02136',
#  'CFHR5',
#  'AC009121.2',
#  'LINC01133',
#  'FAH',
#  'LRRN3',
#  'AC004076.1',
#  'LINC01134',
#  'CLEC18A',
#  'G3BP1',
#  'CCDC96',
#  'CCDC39',
#  'P2RX6',
#  'LINC00115',
#  'AC104461.1',
#  'RBBP4',
#  'ESRP2',
#  'EIF3K',
#  'KRBOX4',
#  'SPDYC',
#  'LINC02262',
#  'TYROBP',
#  'WASHC4',
#  'SHH',
#  'MARCH11',
#  'NOTCH1',
#  'PDSS2',
#  'AL512274.1',
#  'RDH10-AS1',
#  'TRIM61',
#  'ST5',
#  'DBF4',
#  'LINC02454',
#  'FBXL3',
#  'AC008735.3',
#  'C18orf65',
#  'GTSF1',
#  'SPG11',
#  'AL359378.1',
#  'FGD2',
#  'SLC6A17',
#  'SSC5D',
#  'LY6E-DT',
#  'AC129807.1',
#  'LMF1-AS1',
#  'AC099518.6',
#  'LASP1',
#  'AL137802.2',
#  'POP7',
#  'IGSF11',
#  'ZC3H7B',
#  'KCNQ5-AS1',
#  'AC016727.1',
#  'PCDHA12',
#  'CEACAM7',
#  'AC005387.2',
#  'ANKS3',
#  'AC091096.1',
#  'SNX15',
#  'CDCA8',
#  'SAGE1',
#  'LURAP1',
#  'MTF2',
#  'CUL3',
#  'AC013451.2',
#  'RAB3C',
#  'AC090948.2',
#  'ZNF142',
#  'ADSL',
#  'Z82244.1',
#  'BANP',
#  'AIG1',
#  'AP000962.1',
#  'CYP4F12',
#  'FUT7',
#  'DDX5',
#  'RAB39B',
#  'NEK9',
#  'LINC00106',
#  'GRASP',
#  'B4GALT7',
#  'CDC37',
#  'TMC8',
#  'KBTBD11-OT1',
#  'HNRNPH2',
#  'C8orf37-AS1',
#  'AC019254.1',
#  'TMEM132A',
#  'AL589743.5',
#  'FAM95B1',
#  'PEX10',
#  'AC098479.1',
#  'RNPEPL1',
#  'LINC00244',
#  'AC012213.1',
#  'SEC11C',
#  'MED4',
#  'USP1',
#  'TMEM191B',
#  'WTIP',
#  'NARF-AS1',
#  'GDPD3',
#  'TMA7',
#  'CAND2',
#  'ZNF728',
#  'KRTCAP3',
#  'OR4F5',
#  'AL354928.1',
#  'MRPL12',
#  'AC124016.1',
#  'AP003500.2',
#  'AC096564.2',
#  'AC007786.1',
#  'AC005884.2',
#  'AC027701.1',
#  'AC010536.1',
#  'CLK3',
#  'GHRH',
#  'ZNF248',
#  'LINC02220',
#  'AC010105.1',
#  'NMRK1',
#  'TACC1',
#  'SUSD6',
#  'RPL11',
#  'BX890604.1',
#  'C11orf16',
#  'AC083843.3',
#  'AL136099.1',
#  'ITGB1',
#  'ILK',
#  'PCDHA6',
#  'SV2C',
#  'ASGR2',
#  'LINC01516',
#  'AKAP2',
#  'PROX1',
#  'AL354864.1',
#  'MT-CO3',
#  'AC087457.1',
#  'SMG8',
#  'C17orf64',
#  'SDSL',
#  'RCAN3',
#  'BX322234.2',
#  'VWDE',
#  'ATAD1',
#  'USP12',
#  'FBRS',
#  'GABBR2',
#  'AC012339.1',
#  'AL161937.1',
#  'GCNT3',
#  'IL17RE',
#  'LINC01440',
#  'CENPI',
#  'AC136424.2',
#  'PTMA',
#  'GPR179',
#  'AC009093.1',
#  'SLC2A13',
#  'ADORA1',
#  'MAX',
#  'AC074286.1',
#  'GPC3',
#  'WNT7A',
#  'LEFTY2',
#  'SYCP2',
#  'WNT5A',
#  'GOLIM4',
#  'LINC01091',
#  'JMY',
#  'AC098864.1',
#  'MRPS31',
#  'LINC00670',
#  'JMJD8',
#  'AP000654.1',
#  'EPM2A',
#  'PRSS41',
#  'PKIG',
#  'AL691432.2',
#  'AL021937.1',
#  'SIN3B',
#  'LINC00603',
#  'PRIMA1',
#  'ATP5MGL',
#  'OVGP1',
#  'LINC01441',
#  'AC104472.3',
#  'SLC33A1',
#  'FAM177B',
#  'CYP2F1',
#  'GADD45G',
#  'AC009812.3',
#  'MGAT4A',
#  'TMX2',
#  'CTBP2',
#  'PQLC1',
#  'PROCR',
#  'AC023790.2',
#  'SZT2',
#  'AC090518.1',
#  'CA11',
#  'AC007666.1',
#  'ZNF165',
#  'AC122710.2',
#  'RIMS1',
#  'AC016394.1',
#  'AP002784.1',
#  'AL136084.3',
#  'IBSP',
#  'AP000808.2',
#  'MIIP',
#  'AF131216.1',
#  'TRMT1',
#  'TRIM35',
#  'DOCK4',
#  'CPS1',
#  'KCNJ5',
#  'MYBPC1',
#  'BAIAP2L1',
#  'NRG4',
#  'LINC01087',
#  'ZNF223',
#  'SERTAD4-AS1',
#  'AP001198.1',
#  'HSD17B11',
#  'LINC00500',
#  'LINC01046',
#  'SDR16C5',
#  'TENM2',
#  'C1QTNF2',
#  'LIPN',
#  'ADCK1',
#  'TYRP1',
#  'FAM167A-AS1',
#  'FAM71F1',
#  'LINC01703',
#  'FOXP1',
#  'CPNE7',
#  'NR2F6',
#  'AL031963.2',
#  'AC012065.1',
#  'CHML',
#  'C1orf167',
#  'ZBTB14',
#  'GLT8D2',
#  'SMOC2',
#  'TRIM56',
#  'ZC3H8',
#  'LINC02429',
#  'AC006058.1',
#  'AC090204.1',
#  'AC069185.1',
#  'MTFP1',
#  'HSD17B2',
#  'RPP25L',
#  'NAA40',
#  'AC091167.5',
#  'CROCC',
#  'HELZ2',
#  'AL512791.2',
#  'NFKBIB',
#  'PSG2',
#  'NEK11',
#  'AMMECR1',
#  'LINC02319',
#  'PPY',
#  'ZBTB20-AS5',
#  'HDHD3',
#  'AC104123.1',
#  'GPC6',
#  'PCDHB10',
#  'SAR1B',
#  'AC020912.1',
#  'AC009271.1',
#  'B4GALNT3',
#  'CNNM1',
#  'RGN',
#  'PRRC1',
#  'EXOSC9',
#  'GALNT14',
#  'HMGCS2',
#  'FGD5-AS1',
#  'CPAMD8',
#  'EPHB1',
#  'LINC00028',
#  'LY75-CD302',
#  'RIPK1',
#  'NBPF1',
#  'DLG1-AS1',
#  'MED26',
#  'ELMOD1',
#  'LOXL1-AS1',
#  'SLC23A1',
#  'AC091132.5',
#  'AP000345.2',
#  'AL022322.1',
#  'TRPC1',
#  'AC027607.1',
#  'APBA2',
#  'NAA60',
#  'ACSBG2',
#  'LINC01583',
#  'MSTN',
#  'IL24',
#  'LINC01880',
#  'AC114316.2',
#  'MYH4',
#  'LINC00499',
#  'AL583836.1',
#  'HYDIN',
#  'TFEB',
#  'Z69666.1',
#  'AC009570.1',
#  'UGT3A2',
#  'LINC01756',
#  'GLYCTK',
#  'CRISP1',
#  'POMT2',
#  'LINC01856',
#  'AL357052.1',
#  'SAAL1',
#  'COX6A1',
#  'GSPT2',
#  'HIPK4',
#  'AC115618.1',
#  'TACR3',
#  'COMMD3',
#  'KLRF2',
#  'HSPB6',
#  'AL138720.1',
#  'NSA2',
#  'AL121658.1',
#  'AL499616.1',
#  'NAPA-AS1',
#  'ZNF441',
#  'SLC38A7',
#  'HIF3A',
#  'AC108866.1',
#  'AC027307.2',
#  'SLF2',
#  'LINC00434',
#  'AC073896.5',
#  'FH',
#  'SEPT7',
#  'PLAA',
#  'SIMC1',
#  'HEBP2',
#  'PAFAH1B2',
#  'VKORC1',
#  'SOX12',
#  'PSMD14',
#  'XRCC6',
#  'TSLP',
#  'AC103736.1',
#  'KRT10',
#  'APEH',
#  'AC093525.3',
#  'PHIP',
#  'KCNJ2-AS1',
#  'FGFR4',
#  'AC006042.4',
#  'CFAP57',
#  'SPINT1',
#  'TRERF1',
#  'AL023584.1',
#  'HRC',
#  'GORASP1',
#  'SUV39H2',
#  'MPDU1',
#  'RB1-DT',
#  'NEK10',
#  'NR4A1',
#  'OTUD6B-AS1',
#  'AL161751.1',
#  'RAD17',
#  'SNX5',
#  'AP003086.2',
#  'ADRA2A',
#  'LRRTM3',
#  'LINC00525',
#  'GNA15',
#  'LINC02053',
#  'ANKRD33',
#  'MAGEA6',
#  'SPDYE5',
#  'CPLANE1',
#  'AC067747.1',
#  'AP003174.1',
#  'ARHGEF12',
#  'SMIM2',
#  'LGALSL',
#  'CCNE2',
#  'PSMC6',
#  'IMPACT',
#  'AL354809.1',
#  'LINC02185',
#  'ZFP14',
#  'AC093110.1',
#  'IRAK1BP1',
#  'WDR33',
#  'AC011825.4',
#  'GBE1',
#  'C10orf25',
#  'AL606760.3',
#  'DPH5',
#  'SLC17A3',
#  'LRBA',
#  'AC015912.3',
#  'RTF2',
#  'NNT-AS1',
#  'MMP28',
#  'PDZK1',
#  'KIF1A',
#  'PAGE2B',
#  'LINC01423',
#  'PARP2',
#  'LINC01804',
#  'RIPK4',
#  'RASL11A',
#  'ST3GAL2',
#  'AC055717.2',
#  'AL022238.4',
#  'COL4A5',
#  'CRISPLD1',
#  'AC091057.4',
#  'CSDC2',
#  'AL590705.2',
#  'SIGMAR1',
#  'HDDC3',
#  'SMIM10L2B-AS1',
#  'FBXO44',
#  'AC068790.9',
#  'MAGEA2B',
#  'AL135937.1',
#  'WDR36',
#  'C16orf74',
#  'MRPS34',
#  'AP005242.3',
#  'DEDD',
#  'IFITM3',
#  'DLEU7-AS1',
#  'LGR4',
#  'RAI1',
#  'AC116447.1',
#  'STX18',
#  'TMEM18',
#  'PRR5L',
#  'ACTRT3',
#  'AL136309.4',
#  'ANXA13',
#  'AL031283.2',
#  'ANGEL1',
#  'SPARCL1',
#  'AP005229.1',
#  'AC012511.1',
#  'PIGH',
#  'GNPTAB',
#  'FAAH2',
#  'LINC01514',
#  'AC020928.3',
#  'AC078880.3',
#  'PRAMEF14',
#  'CIB2',
#  'AP000302.1',
#  'ORM1',
#  'RPP38',
#  'STRADB',
#  'ATRX',
#  'CRIPT',
#  'PRKCA',
#  'AC108721.1',
#  'ZNF254',
#  'VRK1',
#  'REEP2',
#  'B4GALT6',
#  'TGM3',
#  'AC087623.4',
#  'APOA1-AS',
#  'RPLP2',
#  'LINC02264',
#  'EBF1',
#  'TMEM81',
#  'REXO1',
#  'AC006547.1',
#  'AC104758.4',
#  'LYPLAL1-DT',
#  'TMEM202-AS1',
#  'PGRMC1',
#  'APH1A',
#  'GLT8D1',
#  'IPO7',
#  'LINC01192',
#  'PCIF1',
#  'AC005090.1',
#  'ZNF729',
#  'AL590822.2',
#  'TOP1',
#  'BAG2',
#  'AC008278.2',
#  'ERICH1',
#  'AMOTL1',
#  'AC004825.2',
#  'SRSF6',
#  'UTP23',
#  'MYO9B',
#  'ADAM19',
#  'AC005842.1',
#  'ACTL6B',
#  'ADCY5',
#  'TOR1AIP1',
#  'SLC39A2',
#  'ITGA11',
#  'FIS1',
#  'AC055874.1',
#  'AC091691.2',
#  'KLHL8',
#  'AP5Z1',
#  'CDC42BPG',
#  'PSMB2',
#  'ZNF431',
#  'ADRB2',
#  'AL513217.1',
#  'PCID2',
#  'CCDC155',
#  'UBE2D4',
#  'PPP1R14D',
#  'TIMM8A',
#  'AC010890.1',
#  'IFT81',
#  'SHMT1',
#  'AC015802.4',
#  'SPECC1',
#  'IL10RB-DT',
#  'TEKT4',
#  'TRMO',
#  'BIRC7',
#  'FXYD6',
#  'LINC02216',
#  'CCL25',
#  'NGLY1',
#  'RNGTT',
#  'C2orf80',
#  'LRRC45',
#  'ZNF589',
#  'NANOS1',
#  'THAP11',
#  'CDRT1',
#  'CCDC198',
#  'AC100872.1',
#  'NEK7',
#  'AC068870.2',
#  'DRAIC',
#  'SCHIP1',
#  'ZNF135',
#  'SLC25A45',
#  'HIGD2A',
#  'TH2LCRR',
#  'ADH1C',
#  'RAD54L',
#  'MRPL44',
#  'XBP1',
#  'LINC02283',
#  'ZMAT2',
#  'N6AMT1',
#  'TSHB',
#  'AC005695.3',
#  'TLR8',
#  'AC087289.3',
#  'HRNR',
#  'SLC26A10',
#  'AP001469.1',
#  'APOBEC3H',
#  'AC024267.3',
#  'AC106791.1',
#  'AC021739.3',
#  'HSDL1',
#  'GMEB1',
#  'CCT5',
#  'AC007249.1',
#  'ZNF75D',
#  'CLMP',
#  'PGS1',
#  'MUC15',
#  'MORC1',
#  'CACNA1F',
#  'IL34',
#  'AL451042.2',
#  'IFNA10',
#  'RNF219',
#  'MBD3L2B',
#  'MAJIN',
#  'AC112484.1',
#  'GNRH1',
#  'AC126283.2',
#  'SPSB2',
#  'LINC01205',
#  'MXRA5',
#  'IGBP1-AS2',
#  'MAU2',
#  'NUAK1',
#  'AC090970.2',
#  'AL096711.2',
#  'GINS1',
#  'AL157823.2',
#  'SLC26A2',
#  'AC106894.1',
#  'AC084757.3',
#  'AL157400.2',
#  'SMTNL2',
#  'SPATA18',
#  'FCF1',
#  'C1QTNF12',
#  'NR1I3',
#  'AC105362.1',
#  'SGK2',
#  'TRIB2',
#  'IL18BP',
#  'ZCCHC24',
#  'BCAP31',
#  'ENPP7',
#  'AC073311.1',
#  'ZBTB48',
#  'LINC00491',
#  'FSTL5',
#  'LDB2',
#  'AC087241.3',
#  'OTOP3',
#  'AC010654.1',
#  'LYRM4',
#  'TUBG2',
#  'APOLD1',
#  'GUCY1A2',
#  'HTR1F',
#  'PUM3',
#  'RNF38',
#  'LRIF1',
#  'AC105999.1',
#  'KIF12',
#  'SPEM2',
#  'EOGT',
#  'ESYT3',
#  'FANK1',
#  'ZBTB8A',
#  'DEFB108B',
#  'C11orf1',
#  'LPIN2',
#  'AC010320.4',
#  'SAMD8',
#  'TMEM206',
#  'UGT1A8',
#  'AC128687.2',
#  'CXCR6',
#  'AC114546.2',
#  'LINC02377',
#  'AC004943.3',
#  'AC084018.2',
#  'SPDYE2B',
#  'KCNF1',
#  'SKA3',
#  'AL158198.1',
#  'IVD',
#  'AC004969.1',
#  'AKR1C1',
#  'YTHDF3',
#  'CELA1',
#  'SEC61G',
#  'AL611929.1',
#  'ENPP4',
#  'KPTN',
#  'UGT1A1',
#  'ARRDC2',
#  'AC009690.2',
#  'SMC2-AS1',
#  'CD209',
#  'ZFAND5',
#  'PDLIM3',
#  'PRDM15',
#  'AC026254.2',
#  'FSIP2-AS1',
#  'YIPF3',
#  'AC022382.1',
#  'AL136369.2',
#  'ZNF423',
#  'AJM1',
#  'AC079942.1',
#  'CEP162',
#  'POLR3A',
#  'USP21',
#  'ZNF684',
#  'AC112721.1',
#  'PHF6',
#  'PTPRJ-AS1',
#  'DHTKD1',
#  'OR2A1-AS1',
#  'AC008700.1',
#  'LINC00862',
#  'AWAT2',
#  'SLC16A10',
#  'MYMK',
#  'AP001462.1',
#  'NMT2',
#  'NSD2',
#  'LINC02517',
#  'ELAC1',
#  'FBXO34',
#  'DDX3X',
#  'AKR1C3',
#  'PNP',
#  'SPIRE1',
#  'MRAP2',
#  'LINC02249',
#  'AC243585.1',
#  'PPAT',
#  'LINC00665',
#  'TSPEAR-AS2',
#  'KIAA1841',
#  'USP2',
#  'RIC8B',
#  'AC102945.1',
#  'LINC00452',
#  'ZNF763',
#  'FP700111.1',
#  'IYD',
#  'USP16',
#  'ZNF761',
#  'AL731533.2',
#  'MFSD2B',
#  'LINC01807',
#  'AC004148.2',
#  'PSD3',
#  'STYK1',
#  'CACNB4',
#  'MMP13',
#  'PHF1',
#  'CCDC163',
#  'ZNF518B',
#  'GAS2L2',
#  'GTF2A1',
#  'DAPK2',
#  'CYSLTR1',
#  'BMI1',
#  'HSPA9',
#  'ZNF710',
#  'RUFY2',
#  'GOLGA6L6',
#  'ZNF468',
#  'ZRSR2',
#  'ADAMTS12',
#  'NGFR',
#  'SPINT2',
#  'AC092287.1',
#  'AC011498.6',
#  'AP2S1',
#  'AC145422.1',
#  'MYOCOS',
#  'C1orf109',
#  'GRIN2D',
#  'LINC00838',
#  'MPP5',
#  'AL121601.1',
#  'R3HDM2',
#  'CD177',
#  'AC016590.3',
#  'NES',
#  'NPIPB5',
#  'UTP25',
#  'ZSWIM2',
#  'PRDX2',
#  'STIP1',
#  'AC079834.2',
#  'FBXO3',
#  'RPL24',
#  'C7orf31',
#  'EGR2',
#  'AL137145.2',
#  'RTCA-AS1',
#  'LINC01960',
#  'AC100818.1',
#  'HCG27',
#  'LENEP',
#  'GGT1',
#  'MRPL51',
#  'MYO5C',
#  'FBXO2',
#  'TAB3',
#  'AL035415.1',
#  'LINC02126',
#  'FXR2',
#  'KLRD1',
#  'NRN1',
#  'AC104304.1',
#  'ARPC1B',
#  'GRIA4',
#  'PPP1R14B',
#  'HAR1B',
#  'TIMM17A',
#  'BRD3OS',
#  'VMA21',
#  'AC078929.1',
#  'AL663074.1',
#  'CIITA',
#  'DDX3Y',
#  'PSG7',
#  'SPTBN1',
#  'ANKLE1',
#  'PAN3',
#  'AP003550.1',
#  'AL133351.1',
#  'AC107027.1',
#  'AP003354.2',
#  'PIK3CD-AS2',
#  'OR2M3',
#  'ANAPC2',
#  'TRIM49B',
#  'DPM1',
#  'AC123768.4',
#  'MICU1',
#  'AC137932.1',
#  'CEP78',
#  'AL360268.2',
#  'UBQLN1',
#  'TCF7',
#  'AL133240.1',
#  'CDKN2B',
#  'METTL17',
#  'CAV2',
#  'ST7',
#  'AC008736.1',
#  'MALSU1',
#  'HECA',
#  'CDC7',
#  'KLHL34',
#  'GFRA1',
#  'TNFAIP6',
#  'AL353751.1',
#  'TGFBR1',
#  'AC092131.1',
#  'AC110792.2',
#  'EIF3C',
#  'AC008948.1',
#  'LINC01470',
#  'AC093635.1',
#  'AC007422.1',
#  'DPRX',
#  'AL354694.1',
#  'AC115618.2',
#  'CRK',
#  'TMEM179',
#  'LINC02175',
#  'STC1',
#  'ADAMTSL5',
#  'CGA',
#  'GP6',
#  'WDPCP',
#  'RUNDC3A',
#  'TMCO4',
#  'LINC02478',
#  'FAM239A',
#  'NEXN',
#  'EPB41L5',
#  'NMNAT3',
#  'RNASEH2B',
#  'C1orf158',
#  'PBX1',
#  'MAMDC2-AS1',
#  'AC245033.2',
#  'ZMYM2',
#  'ZNF213-AS1',
#  'RACK1',
#  'AC024597.1',
#  'AC012560.1',
#  'TBC1D16',
#  'TXN2',
#  'C1QTNF4',
#  'AC096637.1',
#  'AC007128.1',
#  'TRBV26OR9-2',
#  'AC090282.1',
#  'CSMD2',
#  'AC109454.3',
#  'SPATA8',
#  'AC009269.3',
#  'CPEB4',
#  'RFWD3',
#  'RRP15',
#  'AL356259.1',
#  'AC073957.3',
#  'ADPRHL1',
#  'IL9R',
#  'LINC01771',
#  'AC093903.1',
#  'AC002553.2',
#  'DDTL',
#  'PAX3',
#  'MCPH1-AS1',
#  'NR1I2',
#  'LINC02023',
#  'HNRNPCL3',
#  'C21orf62',
#  'AC067750.1',
#  'FAM117A',
#  'TNS3',
#  'RTP1',
#  'LINC02138',
#  'AL161757.5',
#  'KRIT1',
#  'AC027288.1',
#  'AL137027.1',
#  'HAUS2',
#  'AL049629.1',
#  'PRAMEF11',
#  'AC114810.1',
#  'AL359771.1',
#  'FTCD',
#  'SLC22A3',
#  'BARX2',
#  'TMEM175',
#  'NBPF15',
#  'GSG1',
#  'SLC5A5',
#  'FGF16',
#  'RASGRF2',
#  'BX322562.1',
#  'AL844908.1',
#  'ZNHIT1',
#  'LBX2',
#  'UBXN11',
#  'SRPK2',
#  'AL732314.4',
#  'USP45',
#  'TRIM39',
#  'C8orf76',
#  'HRH2',
#  'NUP62',
#  'PPP6C',
#  'FAR1',
#  'CCDC114',
#  'RAP1GAP2',
#  'MROH8',
#  'PLXNA3',
#  'XPO5',
#  'OXSM',
#  'RTN4',
#  'AF001550.1',
#  'CHL1',
#  'STOX2',
#  'TCEAL5',
#  'VAPA',
#  'SLC37A1',
#  'HSPB11',
#  'AL049548.1',
#  'LINC01349',
#  'INTS14',
#  'AC069544.1',
#  'TMED9',
#  'DNAH2',
#  'AC013470.2',
#  'AL021396.1',
#  'SMIM29',
#  'FGF8',
#  'TTC5',
#  'FAM189B',
#  'GCSAML',
#  'C20orf202',
#  ...}

# %%
genes2 = set(load_genes("treated", "all"))
genes2
# Out:
# {'AL391987.3',
#  'SLC25A53',
#  'SOGA1',
#  'RIPOR2',
#  'SLC16A3',
#  'AC068389.4',
#  'HSP90AB1',
#  'POLR3D',
#  'ZNF236-DT',
#  'LINC02137',
#  'SEC23B',
#  'Z98200.1',
#  'TSPO',
#  'LIPC-AS1',
#  'ACTR6',
#  'NDUFB3',
#  'ETNK2',
#  'AL391261.2',
#  'CDK4',
#  'TMEM98',
#  'MTFR2',
#  'AC125793.1',
#  'AL157359.2',
#  'NCKIPSD',
#  'INSIG1',
#  'TRPM2',
#  'JRK',
#  'AC016831.5',
#  'CMTM8',
#  'PDC',
#  'PAX9',
#  'EPHA5-AS1',
#  'LINC02136',
#  'CFHR5',
#  'AC009121.2',
#  'LINC01133',
#  'FAH',
#  'LRRN3',
#  'AC004076.1',
#  'LINC01134',
#  'CLEC18A',
#  'G3BP1',
#  'CCDC96',
#  'CCDC39',
#  'HDGFL1',
#  'P2RX6',
#  'LINC00115',
#  'AC104461.1',
#  'RBBP4',
#  'ESRP2',
#  'EIF3K',
#  'KRBOX4',
#  'SPDYC',
#  'LINC02262',
#  'TYROBP',
#  'WASHC4',
#  'SHH',
#  'MARCH11',
#  'NOTCH1',
#  'PDSS2',
#  'AL512274.1',
#  'RDH10-AS1',
#  'TRIM61',
#  'ST5',
#  'DBF4',
#  'LINC02454',
#  'FBXL3',
#  'AC008735.3',
#  'C18orf65',
#  'GTSF1',
#  'SPG11',
#  'AL359378.1',
#  'FGD2',
#  'LINC02538',
#  'SLC6A17',
#  'SSC5D',
#  'LY6E-DT',
#  'AC129807.1',
#  'LMF1-AS1',
#  'AC099518.6',
#  'LASP1',
#  'AL137802.2',
#  'LDLRAD4-AS1',
#  'POP7',
#  'IGSF11',
#  'ZC3H7B',
#  'KCNQ5-AS1',
#  'AC016727.1',
#  'CEACAM7',
#  'ANKS3',
#  'AC091096.1',
#  'SNX15',
#  'CDCA8',
#  'SAGE1',
#  'LURAP1',
#  'CHRM2',
#  'MTF2',
#  'CUL3',
#  'AC013451.2',
#  'RAB3C',
#  'AC090948.2',
#  'ZNF142',
#  'ADSL',
#  'Z82244.1',
#  'BANP',
#  'AIG1',
#  'AP000962.1',
#  'CYP4F12',
#  'FUT7',
#  'DDX5',
#  'RAB39B',
#  'NEK9',
#  'LINC00106',
#  'GRASP',
#  'B4GALT7',
#  'CDC37',
#  'B3GALT5-AS1',
#  'TMC8',
#  'KBTBD11-OT1',
#  'HNRNPH2',
#  'AC073530.1',
#  'C8orf37-AS1',
#  'AC019254.1',
#  'AC113391.1',
#  'TMEM132A',
#  'AL589743.5',
#  'FAM95B1',
#  'PEX10',
#  'AC098479.1',
#  'RNPEPL1',
#  'LINC00244',
#  'AC012213.1',
#  'SEC11C',
#  'MED4',
#  'USP1',
#  'TMEM191B',
#  'WTIP',
#  'NARF-AS1',
#  'GDPD3',
#  'TMA7',
#  'CAND2',
#  'ZNF728',
#  'KRTCAP3',
#  'OR4F5',
#  'MRPL12',
#  'AC124016.1',
#  'AC096564.2',
#  'AC007786.1',
#  'AC005884.2',
#  'AC027701.1',
#  'CLK3',
#  'AC010536.1',
#  'GHRH',
#  'ZNF248',
#  'LINC02220',
#  'AC010105.1',
#  'NMRK1',
#  'TACC1',
#  'SUSD6',
#  'RPL11',
#  'BX890604.1',
#  'C11orf16',
#  'AC083843.3',
#  'ITGB1',
#  'ILK',
#  'PCDHA6',
#  'SV2C',
#  'ASGR2',
#  'LINC01516',
#  'AKAP2',
#  'PROX1',
#  'MT-CO3',
#  'AC087457.1',
#  'SMG8',
#  'C17orf64',
#  'SDSL',
#  'RCAN3',
#  'BX322234.2',
#  'VWDE',
#  'ATAD1',
#  'USP12',
#  'FBRS',
#  'GABBR2',
#  'AC012339.1',
#  'AL161937.1',
#  'GCNT3',
#  'IL17RE',
#  'LINC01440',
#  'CENPI',
#  'AC136424.2',
#  'PTMA',
#  'GPR179',
#  'AC087667.1',
#  'SLC2A13',
#  'AC009093.1',
#  'ADORA1',
#  'MAX',
#  'AC074286.1',
#  'GPC3',
#  'WNT7A',
#  'LEFTY2',
#  'SYCP2',
#  'AC025871.1',
#  'WNT5A',
#  'GOLIM4',
#  'KAAG1',
#  'LINC01091',
#  'JMY',
#  'AC098864.1',
#  'MRPS31',
#  'LINC00670',
#  'JMJD8',
#  'AP000654.1',
#  'EPM2A',
#  'PRSS41',
#  'PKIG',
#  'AL691432.2',
#  'LINC00603',
#  'SIN3B',
#  'AL021937.1',
#  'TCEAL3-AS1',
#  'PRIMA1',
#  'ATP5MGL',
#  'OVGP1',
#  'LINC01441',
#  'AC104472.3',
#  'SLC33A1',
#  'FAM177B',
#  'CYP2F1',
#  'GADD45G',
#  'AC009812.3',
#  'MGAT4A',
#  'AL357033.1',
#  'TMX2',
#  'CTBP2',
#  'PQLC1',
#  'PROCR',
#  'AC023790.2',
#  'SZT2',
#  'AC090518.1',
#  'CA11',
#  'ZNF165',
#  'AC122710.2',
#  'AC016394.1',
#  'RIMS1',
#  'AP002784.1',
#  'AL136084.3',
#  'IBSP',
#  'AP000808.2',
#  'MIIP',
#  'AF131216.1',
#  'TRMT1',
#  'TRIM35',
#  'DOCK4',
#  'CPS1',
#  'KCNJ5',
#  'MYBPC1',
#  'BAIAP2L1',
#  'NRG4',
#  'LINC01087',
#  'ZNF223',
#  'SERTAD4-AS1',
#  'AP001198.1',
#  'HSD17B11',
#  'LINC00500',
#  'SDR16C5',
#  'TENM2',
#  'C1QTNF2',
#  'LIPN',
#  'ADCK1',
#  'TYRP1',
#  'FAM167A-AS1',
#  'FAM71F1',
#  'LINC01703',
#  'FOXP1',
#  'CPNE7',
#  'NR2F6',
#  'AL031963.2',
#  'AC012065.1',
#  'CHML',
#  'C1orf167',
#  'ZBTB14',
#  'GLT8D2',
#  'SMOC2',
#  'TRIM56',
#  'ZC3H8',
#  'LINC02429',
#  'AC006058.1',
#  'MTFP1',
#  'AC069185.1',
#  'AC090204.1',
#  'HSD17B2',
#  'RPP25L',
#  'NAA40',
#  'AC091167.5',
#  'CROCC',
#  'HELZ2',
#  'AL512791.2',
#  'NFKBIB',
#  'UTS2R',
#  'NEK11',
#  'AMMECR1',
#  'LINC02319',
#  'PPY',
#  'ZBTB20-AS5',
#  'HDHD3',
#  'AC104123.1',
#  'GPC6',
#  'PCDHB10',
#  'SAR1B',
#  'AC020912.1',
#  'AC009271.1',
#  'B4GALNT3',
#  'CNNM1',
#  'RGN',
#  'PRRC1',
#  'EXOSC9',
#  'GALNT14',
#  'HMGCS2',
#  'FGD5-AS1',
#  'CPAMD8',
#  'EPHB1',
#  'LINC00028',
#  'LY75-CD302',
#  'RIPK1',
#  'NBPF1',
#  'DLG1-AS1',
#  'MED26',
#  'ELMOD1',
#  'AL161733.1',
#  'LOXL1-AS1',
#  'SLC23A1',
#  'AC091132.5',
#  'AP000345.2',
#  'AL022322.1',
#  'TRPC1',
#  'AC027607.1',
#  'APBA2',
#  'NAA60',
#  'ACSBG2',
#  'LINC01583',
#  'MSTN',
#  'IL24',
#  'LINC01880',
#  'AC114316.2',
#  'MYH4',
#  'AL161646.2',
#  'AL035443.1',
#  'LINC00499',
#  'AL583836.1',
#  'HYDIN',
#  'TFEB',
#  'Z69666.1',
#  'AC009570.1',
#  'UGT3A2',
#  'LINC01756',
#  'GLYCTK',
#  'ACP4',
#  'CRISP1',
#  'POMT2',
#  'LINC01856',
#  'AL357052.1',
#  'SAAL1',
#  'COX6A1',
#  'GSPT2',
#  'AC023932.1',
#  'HIPK4',
#  'AC115618.1',
#  'TACR3',
#  'COMMD3',
#  'KLRF2',
#  'HSPB6',
#  'AL138720.1',
#  'NSA2',
#  'AL121658.1',
#  'SLC38A7',
#  'ZNF441',
#  'NAPA-AS1',
#  'AC027307.2',
#  'AC108866.1',
#  'HIF3A',
#  'SLF2',
#  'LINC00434',
#  'FH',
#  'SEPT7',
#  'PLAA',
#  'SIMC1',
#  'HEBP2',
#  'PAFAH1B2',
#  'VKORC1',
#  'SOX12',
#  'PSMD14',
#  'XRCC6',
#  'TSLP',
#  'AC103736.1',
#  'KRT10',
#  'APEH',
#  'AC093525.3',
#  'PHIP',
#  'KCNJ2-AS1',
#  'FGFR4',
#  'AC006042.4',
#  'CFAP57',
#  'SPINT1',
#  'TRERF1',
#  'AL023584.1',
#  'HRC',
#  'GORASP1',
#  'SUV39H2',
#  'MPDU1',
#  'RB1-DT',
#  'NEK10',
#  'NR4A1',
#  'OTUD6B-AS1',
#  'AL161751.1',
#  'RAD17',
#  'SNX5',
#  'AP003086.2',
#  'ADRA2A',
#  'LRRTM3',
#  'LINC00525',
#  'GNA15',
#  'LINC02053',
#  'MAGEA6',
#  'SPDYE5',
#  'CPLANE1',
#  'AC067747.1',
#  'AP003174.1',
#  'ARHGEF12',
#  'SMIM2',
#  'LINC01665',
#  'LGALSL',
#  'CCNE2',
#  'PSMC6',
#  'IMPACT',
#  'AL354809.1',
#  'LINC02185',
#  'ZFP14',
#  'AC093110.1',
#  'IRAK1BP1',
#  'WDR33',
#  'AC011825.4',
#  'GBE1',
#  'C10orf25',
#  'AL606760.3',
#  'DPH5',
#  'SLC17A3',
#  'LRBA',
#  'AC015912.3',
#  'RTF2',
#  'NNT-AS1',
#  'MMP28',
#  'KIF1A',
#  'PDZK1',
#  'PAGE2B',
#  'LINC01423',
#  'PARP2',
#  'LINC01804',
#  'RIPK4',
#  'RASL11A',
#  'ST3GAL2',
#  'AC055717.2',
#  'AC093627.7',
#  'COL4A5',
#  'CRISPLD1',
#  'AC091057.4',
#  'CSDC2',
#  'SIGMAR1',
#  'HDDC3',
#  'SMIM10L2B-AS1',
#  'FBXO44',
#  'AC068790.9',
#  'AL121829.1',
#  'AL135937.1',
#  'WDR36',
#  'C16orf74',
#  'MRPS34',
#  'DEDD',
#  'IFITM3',
#  'DLEU7-AS1',
#  'LGR4',
#  'RAI1',
#  'AC116447.1',
#  'STX18',
#  'SRGAP3-AS3',
#  'TMEM18',
#  'PRR5L',
#  'ACTRT3',
#  'ANXA13',
#  'ANGEL1',
#  'SPARCL1',
#  'AP005229.1',
#  'PIGH',
#  'GNPTAB',
#  'FAAH2',
#  'LINC01514',
#  'AC020928.3',
#  'AC078880.3',
#  'CIB2',
#  'AP000302.1',
#  'ORM1',
#  'AC021127.1',
#  'RPP38',
#  'STRADB',
#  'ATRX',
#  'CRIPT',
#  'PRKCA',
#  'LINC01052',
#  'AC108721.1',
#  'ZNF254',
#  'AC104688.1',
#  'VRK1',
#  'REEP2',
#  'B4GALT6',
#  'TGM3',
#  'AC087623.4',
#  'APOA1-AS',
#  'RPLP2',
#  'TMEM81',
#  'EBF1',
#  'REXO1',
#  'AC006547.1',
#  'AC104758.4',
#  'TMEM202-AS1',
#  'LYPLAL1-DT',
#  'PGRMC1',
#  'APH1A',
#  'GLT8D1',
#  'IPO7',
#  'LINC01192',
#  'PCIF1',
#  'AC005090.1',
#  'ZNF729',
#  'AL590822.2',
#  'TOP1',
#  'BAG2',
#  'AC008278.2',
#  'ERICH1',
#  'AMOTL1',
#  'AC004825.2',
#  'LINC02488',
#  'SRSF6',
#  'UTP23',
#  'MYO9B',
#  'ADAM19',
#  'AC005842.1',
#  'ACTL6B',
#  'ADCY5',
#  'TOR1AIP1',
#  'SLC39A2',
#  'ITGA11',
#  'FIS1',
#  'AC134682.1',
#  'AC091691.2',
#  'KLHL8',
#  'AP5Z1',
#  'CDC42BPG',
#  'PSMB2',
#  'ZNF431',
#  'ADRB2',
#  'AL513217.1',
#  'PCID2',
#  'CCDC155',
#  'UBE2D4',
#  'PPP1R14D',
#  'TIMM8A',
#  'AC010890.1',
#  'IFT81',
#  'SHMT1',
#  'AC015802.4',
#  'SPECC1',
#  'IL10RB-DT',
#  'TEKT4',
#  'TRMO',
#  'BIRC7',
#  'FXYD6',
#  'LINC02216',
#  'CCL25',
#  'NGLY1',
#  'RNGTT',
#  'C2orf80',
#  'LRRC45',
#  'ZNF589',
#  'NANOS1',
#  'THAP11',
#  'CDRT1',
#  'CCDC198',
#  'AC100872.1',
#  'NEK7',
#  'AC068870.2',
#  'DRAIC',
#  'SCHIP1',
#  'ZNF135',
#  'SLC25A45',
#  'HIGD2A',
#  'TH2LCRR',
#  'ADH1C',
#  'RAD54L',
#  'MRPL44',
#  'XBP1',
#  'ZMAT2',
#  'N6AMT1',
#  'TSHB',
#  'AC005695.3',
#  'TLR8',
#  'AC087289.3',
#  'HRNR',
#  'SLC26A10',
#  'AC016933.1',
#  'APOBEC3H',
#  'AC024267.3',
#  'AC106791.1',
#  'AC021739.3',
#  'HSDL1',
#  'GMEB1',
#  'CCT5',
#  'AC007249.1',
#  'ZNF75D',
#  'CLMP',
#  'PGS1',
#  'MUC15',
#  'MORC1',
#  'CACNA1F',
#  'IL34',
#  'AL451042.2',
#  'RNF219',
#  'MBD3L2B',
#  'MAJIN',
#  'AC112484.1',
#  'GNRH1',
#  'AC126283.2',
#  'SPSB2',
#  'LINC01205',
#  'MXRA5',
#  'IGBP1-AS2',
#  'MAU2',
#  'NUAK1',
#  'AC090970.2',
#  'AL096711.2',
#  'GINS1',
#  'AL157823.2',
#  'SLC26A2',
#  'AC106894.1',
#  'AC084757.3',
#  'AL157400.2',
#  'SMTNL2',
#  'SPATA18',
#  'FCF1',
#  'C1QTNF12',
#  'NR1I3',
#  'SGK2',
#  'TRIB2',
#  'IL18BP',
#  'BCAP31',
#  'ZCCHC24',
#  'AC073311.1',
#  'ZBTB48',
#  'LINC00491',
#  'FSTL5',
#  'LDB2',
#  'AC087241.3',
#  'OTOP3',
#  'AC010654.1',
#  'LYRM4',
#  'TUBG2',
#  'APOLD1',
#  'GUCY1A2',
#  'HTR1F',
#  'PUM3',
#  'RNF38',
#  'LRIF1',
#  'AC007362.1',
#  'AC105999.1',
#  'KIF12',
#  'AC018685.2',
#  'SPEM2',
#  'EOGT',
#  'ESYT3',
#  'FANK1',
#  'ZBTB8A',
#  'C11orf1',
#  'LPIN2',
#  'AC010320.4',
#  'SAMD8',
#  'TMEM206',
#  'UGT1A8',
#  'AC128687.2',
#  'CXCR6',
#  'AC114546.2',
#  'LINC02377',
#  'AC004943.3',
#  'AC084018.2',
#  'SPDYE2B',
#  'SKA3',
#  'AL158198.1',
#  'IVD',
#  'AC004969.1',
#  'AKR1C1',
#  'YTHDF3',
#  'CELA1',
#  'SEC61G',
#  'ENPP4',
#  'KPTN',
#  'UGT1A1',
#  'ARRDC2',
#  'SMC2-AS1',
#  'CD209',
#  'CAPN6',
#  'ZFAND5',
#  'PDLIM3',
#  'PRDM15',
#  'AC026254.2',
#  'FSIP2-AS1',
#  'YIPF3',
#  'AC022382.1',
#  'AL136369.2',
#  'ZNF423',
#  'AJM1',
#  'AC079942.1',
#  'POLR3A',
#  'CEP162',
#  'USP21',
#  'AC112721.1',
#  'ZNF684',
#  'PHF6',
#  'PTPRJ-AS1',
#  'DHTKD1',
#  'OR2A1-AS1',
#  'AC008700.1',
#  'LINC00862',
#  'AWAT2',
#  'SLC16A10',
#  'AC012170.3',
#  'MYMK',
#  'AP001462.1',
#  'NMT2',
#  'NSD2',
#  'ELAC1',
#  'FBXO34',
#  'DDX3X',
#  'AKR1C3',
#  'PNP',
#  'SPIRE1',
#  'MRAP2',
#  'LINC02249',
#  'AC243585.1',
#  'PPAT',
#  'LINC00665',
#  'TSPEAR-AS2',
#  'KIAA1841',
#  'USP2',
#  'RIC8B',
#  'AC102945.1',
#  'LINC00452',
#  'ZNF763',
#  'FP700111.1',
#  'IYD',
#  'USP16',
#  'ZNF761',
#  'AL731533.2',
#  'MFSD2B',
#  'LINC01807',
#  'AC004148.2',
#  'PSD3',
#  'STYK1',
#  'CACNB4',
#  'MMP13',
#  'PHF1',
#  'CCDC163',
#  'LINC00305',
#  'ZNF518B',
#  'GAS2L2',
#  'GTF2A1',
#  'DAPK2',
#  'CYSLTR1',
#  'HSPA9',
#  'BMI1',
#  'ZNF710',
#  'RUFY2',
#  'GOLGA6L6',
#  'ZNF468',
#  'ZRSR2',
#  'ADAMTS12',
#  'NGFR',
#  'SPINT2',
#  'AC092287.1',
#  'AC011498.6',
#  'AP2S1',
#  'AC145422.1',
#  'MYOCOS',
#  'C1orf109',
#  'GRIN2D',
#  'MPP5',
#  'AL121601.1',
#  'R3HDM2',
#  'AC016590.3',
#  'NES',
#  'NPIPB5',
#  'UTP25',
#  'ZSWIM2',
#  'PRDX2',
#  'STIP1',
#  'AC079834.2',
#  'FBXO3',
#  'RPL24',
#  'AL137145.2',
#  'EGR2',
#  'C7orf31',
#  'RTCA-AS1',
#  'LINC01960',
#  'AC100818.1',
#  'HCG27',
#  'LENEP',
#  'GGT1',
#  'MRPL51',
#  'AC020595.1',
#  'MYO5C',
#  'FBXO2',
#  'TAB3',
#  'AL035415.1',
#  'LINC02126',
#  'FXR2',
#  'NRN1',
#  'KLRD1',
#  'AC104304.1',
#  'ARPC1B',
#  'GRIA4',
#  'PPP1R14B',
#  'HAR1B',
#  'TIMM17A',
#  'BRD3OS',
#  'VMA21',
#  'AC078929.1',
#  'AL663074.1',
#  'CIITA',
#  'DDX3Y',
#  'PSG7',
#  'SPTBN1',
#  'ANKLE1',
#  'PAN3',
#  'AP003550.1',
#  'AL133351.1',
#  'AC107027.1',
#  'AP003354.2',
#  'PIK3CD-AS2',
#  'OR2M3',
#  'ANAPC2',
#  'TRIM49B',
#  'DPM1',
#  'C2CD4B',
#  'AC123768.4',
#  'MICU1',
#  'AC137932.1',
#  'CEP78',
#  'AL360268.2',
#  'UBQLN1',
#  'TCF7',
#  'AL133240.1',
#  'CDKN2B',
#  'METTL17',
#  'CAV2',
#  'ST7',
#  'AC008736.1',
#  'MALSU1',
#  'HECA',
#  'CDC7',
#  'GFRA1',
#  'TNFAIP6',
#  'AL353751.1',
#  'TGFBR1',
#  'AC092131.1',
#  'AC110792.2',
#  'EIF3C',
#  'AC008948.1',
#  'LINC01470',
#  'AC090164.4',
#  'AC093635.1',
#  'AC007422.1',
#  'DPRX',
#  'AL354694.1',
#  'AC115618.2',
#  'CRK',
#  'TMEM179',
#  'LINC02175',
#  'STC1',
#  'ADAMTSL5',
#  'CGA',
#  'GP6',
#  'WDPCP',
#  'RUNDC3A',
#  'TMCO4',
#  'LINC02478',
#  'FAM239A',
#  'NEXN',
#  'EPB41L5',
#  'NMNAT3',
#  'RNASEH2B',
#  'C1orf158',
#  'PBX1',
#  'MAMDC2-AS1',
#  'AL022396.1',
#  'AC245033.2',
#  'ZMYM2',
#  'ZNF213-AS1',
#  'RACK1',
#  'AC024597.1',
#  'AC012560.1',
#  'TBC1D16',
#  'TXN2',
#  'C1QTNF4',
#  'AC096637.1',
#  'AC007128.1',
#  'TRBV26OR9-2',
#  'AC090282.1',
#  'CSMD2',
#  'AC109454.3',
#  'SPATA8',
#  'AC009269.3',
#  'CPEB4',
#  'RFWD3',
#  'RRP15',
#  'AC073957.3',
#  'ADPRHL1',
#  'IL9R',
#  'LINC01771',
#  'AC093903.1',
#  'AC002553.2',
#  'DDTL',
#  'PAX3',
#  'MCPH1-AS1',
#  'NR1I2',
#  'C21orf62',
#  'AC067750.1',
#  'FAM117A',
#  'TNS3',
#  'RTP1',
#  'AC044840.1',
#  'LINC02138',
#  'AL161757.5',
#  'KRIT1',
#  'AC027288.1',
#  'AL137027.1',
#  'AL121768.1',
#  'HAUS2',
#  'AL049629.1',
#  'FTCD',
#  'AL359771.1',
#  'SLC22A3',
#  'BARX2',
#  'TMEM175',
#  'NBPF15',
#  'GSG1',
#  'SLC5A5',
#  'FGF16',
#  'RASGRF2',
#  'BX322562.1',
#  'AL844908.1',
#  'ZNHIT1',
#  'LBX2',
#  'UBXN11',
#  'SRPK2',
#  'AL732314.4',
#  'USP45',
#  'TRIM39',
#  'C8orf76',
#  'HRH2',
#  'NUP62',
#  'PPP6C',
#  'FAR1',
#  'CCDC114',
#  'RAP1GAP2',
#  'MROH8',
#  'PLXNA3',
#  'XPO5',
#  'OXSM',
#  'RTN4',
#  'AF001550.1',
#  'CHL1',
#  'STOX2',
#  'TCEAL5',
#  'VAPA',
#  'SLC37A1',
#  'HSPB11',
#  'LINC00972',
#  'AL049548.1',
#  'LINC01349',
#  'INTS14',
#  'AC069544.1',
#  'TMED9',
#  'DNAH2',
#  'AC013470.2',
#  'FCN1',
#  'AL021396.1',
#  'SMIM29',
#  'FGF8',
#  'DIRC3-AS1',
#  'TTC5',
#  'FAM189B',
#  'GCSAML',
#  'FAAP20',
#  ...}

# %%
print(len(genes1), len(genes2), len(genes1) + len(genes2))
# Out:
# 26740 26590 53330

# %%
symdiff = genes1.symmetric_difference(genes2)
symdiff
# Out:
# {'AL023581.1',
#  'AC018946.1',
#  'PRAMEF4',
#  'AC018511.1',
#  'AL391421.1',
#  'AL021920.3',
#  'LINC00557',
#  'HDGFL1',
#  'GKN1',
#  'AC008619.1',
#  'AC067852.2',
#  'AP003721.4',
#  'LINC02538',
#  'AL136373.1',
#  'LDLRAD4-AS1',
#  'PCDHA12',
#  'AC005387.2',
#  'OR52N5',
#  'CHRM2',
#  'B3GALT5-AS1',
#  'AC073530.1',
#  'AC113391.1',
#  'HCG24',
#  'SST',
#  'AL354928.1',
#  'LINC01602',
#  'AP003500.2',
#  'LINC01937',
#  'AL136099.1',
#  'AL354864.1',
#  'AC007347.1',
#  'DBNDD2',
#  'AC103879.1',
#  'AC087667.1',
#  'AP002884.2',
#  'AC025871.1',
#  'MT1HL1',
#  'KAAG1',
#  'TCEAL3-AS1',
#  'LINC01537',
#  'LINC02294',
#  'AL357033.1',
#  'AC007666.1',
#  'LHX3',
#  'LINC01046',
#  'CSHL1',
#  'UTS2R',
#  'PSG2',
#  'LINC00279',
#  'AC090510.2',
#  'NPY4R2',
#  'AL161733.1',
#  'ODF3',
#  'AL161646.2',
#  'AL035443.1',
#  'FETUB',
#  'ACP4',
#  'AC079466.2',
#  'AC023932.1',
#  'AL499616.1',
#  'AC073896.5',
#  'ALPP',
#  'AC015771.1',
#  'AL645937.2',
#  'AC027018.1',
#  'F9',
#  'ANKRD33',
#  'SP5',
#  'AC068946.2',
#  'AC107982.2',
#  'LINC01665',
#  'LINC01346',
#  'AL022238.4',
#  'AC093627.7',
#  'AL590705.2',
#  'AL121829.1',
#  'MAGEA2B',
#  'AP005242.3',
#  'AC097535.1',
#  'SRGAP3-AS3',
#  'AL136309.4',
#  'AL031283.2',
#  'LINC01445',
#  'AC012511.1',
#  'AC243965.1',
#  'PRAMEF14',
#  'AC063976.1',
#  'AC021127.1',
#  'CCDC177',
#  'LINC01052',
#  'BPY2B',
#  'AC104688.1',
#  'LINC02264',
#  'PRAMEF15',
#  'LINC02488',
#  'AC036108.4',
#  'AC068775.1',
#  'AC134682.1',
#  'AC055874.1',
#  'AC087633.1',
#  'LINC00363',
#  'AC010280.2',
#  'LINC01979',
#  'AC005104.1',
#  'LINC02283',
#  'E2F8',
#  'AL590133.1',
#  'AP001469.1',
#  'AC016933.1',
#  'AC069503.3',
#  'AC074035.1',
#  'AC006207.1',
#  'AL592161.1',
#  'AC117834.1',
#  'BSND',
#  'KRTAP4-2',
#  'IFNA10',
#  'AC007250.1',
#  'AC105362.1',
#  'ENPP7',
#  'RIPPLY1',
#  'AC007362.1',
#  'AC018685.2',
#  'DEFB108B',
#  'AL035252.2',
#  'AC022596.1',
#  'AC027243.2',
#  'KCNF1',
#  'AC094108.1',
#  'AL611929.1',
#  'AC009690.2',
#  'CAPN6',
#  'BANCR',
#  'AL355493.2',
#  'TONSL-AS1',
#  'LINC01998',
#  'AC012170.3',
#  'LINC02517',
#  'AC244394.2',
#  'LINC00305',
#  'CKMT1A',
#  'DEFB118',
#  'LINC00838',
#  'CD177',
#  'AL590729.1',
#  'AC020595.1',
#  'AL355376.1',
#  'AC084759.2',
#  'AC090340.1',
#  'C2CD4B',
#  'AC091073.1',
#  'KLHL34',
#  'AC090164.4',
#  'Z97056.1',
#  'MAFA-AS1',
#  'CTAG2',
#  'AL022396.1',
#  'AL110505.1',
#  'AC008033.3',
#  'AL356259.1',
#  'PCGEM1',
#  'LINC02023',
#  'HNRNPCL3',
#  'AC044840.1',
#  'AL121768.1',
#  'AC027031.1',
#  'PRAMEF11',
#  'AC114810.1',
#  'AC010261.2',
#  'CYLC2',
#  'LINC00972',
#  'FCN1',
#  'DIRC3-AS1',
#  'C20orf202',
#  'AC138655.1',
#  'AL355297.2',
#  'AC011396.1',
#  'AL157395.1',
#  'AC013727.1',
#  'BX005132.2',
#  'ASB18',
#  'SSU72P7',
#  'AC048383.1',
#  'LINC00911',
#  'GPR12',
#  'LINC02561',
#  'HOXB7',
#  'BX539320.1',
#  'ADCYAP1',
#  'LINC02590',
#  'AC091435.2',
#  'AL034550.2',
#  'AL109954.1',
#  'AL022097.1',
#  'BSX',
#  'AL138775.1',
#  'AC022021.1',
#  'AC008852.1',
#  'SLC17A6',
#  'AC007342.4',
#  'LINC00395',
#  'AC243960.3',
#  'RNF223',
#  'AC114730.3',
#  'AC108037.1',
#  'GSG1L2',
#  'AC026434.1',
#  'TEX54',
#  'AC007952.6',
#  'AC010132.1',
#  'AC061709.1',
#  'BPIFB3',
#  'KLHL6-AS1',
#  'AL078601.2',
#  'AC093689.1',
#  'AC023137.1',
#  'AP001065.1',
#  'KCNQ1DN',
#  'AL139121.1',
#  'AC004066.2',
#  'AC098934.4',
#  'AL391704.3',
#  'IFNA2',
#  'AC073370.1',
#  'CNTN4-AS1',
#  'SFTPC',
#  'OR4S2',
#  'AL391645.1',
#  'AC005920.4',
#  'PRICKLE4',
#  'AC010680.3',
#  'AC136475.8',
#  'WDR38',
#  'XXYLT1-AS2',
#  'AC007786.3',
#  'GIMAP6',
#  'PRAMEF27',
#  'OR2T2',
#  'AC138907.2',
#  'AC007485.1',
#  'AC106875.2',
#  'AL138812.1',
#  'LINC00701',
#  'REG3G',
#  'AC020743.1',
#  'GATA3-AS1',
#  'AVPR1A',
#  'FAM181B',
#  'AC104971.2',
#  'LLPH-DT',
#  'AL157392.2',
#  'AP002993.1',
#  'AP003973.2',
#  'RNF224',
#  'MT1B',
#  'OR8D4',
#  'LINC01886',
#  'AC018695.2',
#  'AC010776.2',
#  'FAM138F',
#  'LDLRAD1',
#  'LINC00837',
#  'AL008723.1',
#  'LINC01589',
#  'AL513321.2',
#  'AC010907.2',
#  'FOXI3',
#  'FCAMR',
#  'LINC02490',
#  'AC022509.4',
#  'AL355102.5',
#  'AL158069.1',
#  'LIME1',
#  'AC009145.3',
#  'MAL2-AS1',
#  'TRAV30',
#  'OR6C3',
#  'IL9',
#  'AL596223.2',
#  'AC113192.2',
#  'FRG2C',
#  'AC026358.1',
#  'AC139712.3',
#  'AC099398.1',
#  'AL049552.1',
#  'LINC00588',
#  'CRIP3',
#  'HIST1H3F',
#  'AL358473.1',
#  'AL160163.1',
#  'AC106745.1',
#  'LRRC24',
#  'AC019193.3',
#  'AC239802.1',
#  'PRR33',
#  'AL121718.1',
#  'AC005344.1',
#  'CRABP1',
#  'AC104532.2',
#  'LRTM1',
#  'FAM30A',
#  'OR52D1',
#  'ANKRD33B-AS1',
#  'AC131097.2',
#  'AC016382.1',
#  'AC022973.2',
#  'DIO3',
#  'OR6B3',
#  'AL162394.1',
#  'OR2H1',
#  'AL133268.3',
#  'LINC2194',
#  'AC099786.3',
#  'AL136295.4',
#  'LINC01743',
#  'KCNJ18',
#  'AL033384.2',
#  'SPAG11A',
#  'LINC01976',
#  'AC020978.2',
#  'SLITRK2',
#  'FAM138A',
#  'HIST1H4L',
#  'DCAF8L1',
#  'AC010387.1',
#  'AC005616.1',
#  'TRIM77',
#  'AL162385.2',
#  'AC112719.2',
#  'EZR-AS1',
#  'TCAF2C',
#  'AC092376.2',
#  'KRBOX1-AS1',
#  'AL445489.1',
#  'AP003498.1',
#  'AL138799.4',
#  'AC026471.5',
#  'CMA1',
#  'LINC01488',
#  'OPRPN',
#  'RBM11',
#  'TMEM215',
#  'KLK11',
#  'AL390760.1',
#  'AC131097.1',
#  'GZMK',
#  'AC114877.1',
#  'AC009102.2',
#  'PRAMEF18',
#  'AP003969.1',
#  'CCL21',
#  'AC114550.1',
#  'AL391095.3',
#  'AP001180.1',
#  'LINC02271',
#  'RTBDN',
#  'AC131649.1',
#  'Z82249.1',
#  'RLN2',
#  'AL136528.2',
#  'HBZ',
#  'ELOA3',
#  'AC090621.1',
#  'RBMY1A1',
#  'AC244100.2',
#  'AC120498.3',
#  'AC006041.1',
#  'AC093730.1',
#  'AC061961.1',
#  'ARPC4-TTLL3',
#  'AC020905.1',
#  'MACC1-AS1',
#  'AL049765.1',
#  'RNASE8',
#  'AL713999.1',
#  'AC096736.3',
#  'AC104365.2',
#  'LINC02487',
#  'AC068446.2',
#  'AC008060.3',
#  'LINC01688',
#  'TCF15',
#  'AC026780.2',
#  'C1orf68',
#  'LCE1E',
#  'PAGE1',
#  'OR52N4',
#  'CT47A12',
#  'AC012568.1',
#  'CTSE',
#  'RAG2',
#  'AC066613.1',
#  'AL162734.1',
#  'AL159174.1',
#  'AL034346.1',
#  'CRYAA2',
#  'MTUS2-AS2',
#  'CRISP2',
#  'PRSS53',
#  'MAGEA9',
#  'MIR200CHG',
#  'PYDC2',
#  'AC036222.1',
#  'AC092745.1',
#  'AC027243.1',
#  'LINC02101',
#  'IFNA5',
#  'PLA2G4B',
#  'AC016888.1',
#  'LINC01662',
#  'AC068658.1',
#  'OR6C76',
#  'AC024600.1',
#  'AC091932.1',
#  'RFPL4AL1',
#  'AL163192.1',
#  'AC040914.1',
#  'AC106786.1',
#  'AC010335.1',
#  'LINC01972',
#  'AC141257.2',
#  'KLK2',
#  'AC008705.1',
#  'Z99916.3',
#  'LINC01210',
#  'LINC02258',
#  'SLAMF6',
#  'AC073655.1',
#  'AL590666.1',
#  'AP000547.2',
#  'LINC00440',
#  'FP325330.2',
#  'AC148476.1',
#  'AL589765.6',
#  'AP002856.1',
#  'AC011498.4',
#  'CLRN1',
#  'AC133961.1',
#  'AL356652.1',
#  'AL031663.2',
#  'LINC01698',
#  'SRARP',
#  'LINC02330',
#  'LTA',
#  'AF127577.5',
#  'AC078905.1',
#  'LINC02231',
#  'AC105227.1',
#  'AC106754.1',
#  'GPR52',
#  'PRAMEF6',
#  'AL035412.1',
#  'C6orf222',
#  'TRPM5',
#  'AC104071.1',
#  'AP001107.7',
#  'PRY2',
#  'OR4K1',
#  'AC079921.1',
#  'HAND1',
#  'AC019129.2',
#  'AC012613.1',
#  'LCE1B',
#  'MEP1B',
#  'PRAMEF25',
#  'AC187653.1',
#  'AF096876.1',
#  'VAX1',
#  'AP003171.3',
#  'AL583810.3',
#  'AC139491.3',
#  'AL365434.1',
#  'GJB5',
#  'AL157888.1',
#  'LINC00330',
#  'AC068756.1',
#  'KLK5',
#  'AL591806.1',
#  'AC237221.1',
#  'SSU72P3',
#  'MIR1-1HG-AS1',
#  'LINC02509',
#  'NTN3',
#  'AC026894.1',
#  'AL139039.3',
#  'AL023803.2',
#  'AC068993.2',
#  'AL359502.1',
#  'TNFAIP8L2',
#  'AC241644.1',
#  'AC007533.1',
#  'AC093567.1',
#  'LINC02315',
#  'AL161729.2',
#  'AL032819.3',
#  'AP003354.1',
#  'AC007920.1',
#  'NR5A1',
#  'AC000067.1',
#  'AP000696.1',
#  'KRT26',
#  'AC010551.3',
#  'AC007795.1',
#  'EDNRB-AS1',
#  'CCL18',
#  'FGF4',
#  'AL772337.2',
#  'TAL1',
#  'OTOR',
#  'AL157359.1',
#  'AL161804.1',
#  'AC073111.1',
#  'CLDN10-AS1',
#  'AC018410.1',
#  'FP236240.1',
#  'AC069209.1',
#  'TBX5-AS1',
#  'AC007998.3',
#  'PNOC',
#  'AC005013.1',
#  'AC138466.3',
#  'AL590302.2',
#  'DAB1-AS1',
#  'AC104564.4',
#  'AL008638.3',
#  'LINC01507',
#  'AC012507.4',
#  'OR2F2',
#  'AC084064.1',
#  'AC092145.1',
#  'CYP26A1',
#  'AC092326.1',
#  'LINC02060',
#  'AC022893.2',
#  'OR52A5',
#  'AC024028.1',
#  'CLEC4F',
#  'LINC01859',
#  'AF186192.3',
#  'AC244517.7',
#  'IGLV1-50',
#  'AC073172.2',
#  'AC114291.1',
#  'AP003386.1',
#  'AP006333.2',
#  'GTF3C2-AS1',
#  'AC003973.2',
#  'IRF8',
#  'AC027343.3',
#  'HIST1H2AI',
#  'AF131216.3',
#  'AC113346.1',
#  'AL365440.2',
#  'FAM71A',
#  'ACSM2B',
#  'POTEB',
#  'SCRT2',
#  'WNT10A',
#  'PGLYRP3',
#  'AC008448.1',
#  'AC110769.1',
#  'AC068473.2',
#  'AC023161.1',
#  'CLEC3A',
#  'AC099850.3',
#  'IFIT1B',
#  'LINC01770',
#  'AC104662.1',
#  'AL645608.9',
#  'CMTM5',
#  'AC006055.1',
#  'LINC01187',
#  'AC004707.1',
#  'OR1J4',
#  'ADRA2B',
#  'AL928654.3',
#  'AC026786.2',
#  'SPRR2G',
#  'AL157688.1',
#  'AP001464.1',
#  'AC131532.1',
#  'APOB',
#  'AC134980.3',
#  'TMPRSS13',
#  'MYL2',
#  'AC078820.1',
#  'TMEM247',
#  'PRR30',
#  'ROPN1L-AS1',
#  'AC091132.2',
#  'LZTS1-AS1',
#  'AC068580.3',
#  'AL450003.1',
#  'AC106799.3',
#  'AL121992.2',
#  'LINC02420',
#  'AC095030.1',
#  'AC106791.2',
#  'IL2',
#  'AC130324.2',
#  'AC093714.2',
#  'AC004941.1',
#  'SFTPA2',
#  'AC106732.1',
#  'IL20RB-AS1',
#  'TRIM43',
#  'GIMAP1',
#  'AP002439.1',
#  'CT83',
#  'AL353614.1',
#  'AC012409.4',
#  'NEBL-AS1',
#  'C15orf32',
#  'AC093390.2',
#  'AC215217.1',
#  'PHACTR2-AS1',
#  'AC016909.2',
#  'CST5',
#  'OR2T1',
#  'AC010197.1',
#  'LINC01683',
#  'AC060814.5',
#  'AC104211.3',
#  'AP000790.3',
#  'LINC02533',
#  'LINC00387',
#  'AC104187.1',
#  'OR2T5',
#  'GOLGA8F',
#  'TRIM10',
#  'SLC7A3',
#  'SOX21',
#  'KRTAP21-2',
#  'AC027804.1',
#  'AL356310.1',
#  'AP005436.3',
#  'AC110058.1',
#  'AP002802.1',
#  'PSG1',
#  'AL109610.1',
#  'AL133163.3',
#  'AC022558.3',
#  'LINC01893',
#  'LINC02280',
#  'AC100839.1',
#  'CRYGB',
#  'POTEM',
#  'FARSA-AS1',
#  'AC023830.1',
#  'AC092839.1',
#  'AP005131.2',
#  'FAM41AY1',
#  'GAGE12D',
#  'AC023830.2',
#  'AC005865.1',
#  'AL158152.1',
#  'AC005703.2',
#  'AC084866.2',
#  'AC011510.1',
#  'AP002761.2',
#  'AL445471.2',
#  'AC007342.5',
#  'LINC02168',
#  'AC139887.3',
#  'AC022960.1',
#  'C12orf80',
#  'IQCF3',
#  'DEFA3',
#  'AL162726.4',
#  'LINC01868',
#  'AL356753.1',
#  'LINC00645',
#  'AL035541.1',
#  'LINC02415',
#  'FAM205A',
#  'AC018730.1',
#  'LALBA',
#  'AL133456.1',
#  'AC005224.2',
#  'LGSN',
#  'AC005540.1',
#  'AL022344.1',
#  'SSU72P4',
#  'AC137810.1',
#  'AC108174.1',
#  'AL050320.1',
#  'PANX3',
#  'AC130466.1',
#  'AC097110.1',
#  'AC012307.1',
#  'PRF1',
#  'AC102953.1',
#  'AC011500.3',
#  'AC104117.5',
#  'OR2V1',
#  'LINC01489',
#  'AL353801.1',
#  'AC027013.1',
#  'NDFIP2-AS1',
#  'FGB',
#  'RAI1-AS1',
#  'PAX1',
#  'ARHGAP8',
#  'KLK7',
#  'ATXN8OS',
#  'AL358876.2',
#  'RD3',
#  'LCN15',
#  'AC104350.1',
#  'H2AFB1',
#  'AC020612.3',
#  'HSD3B2',
#  'LINC02390',
#  'AC116351.2',
#  'AC117460.1',
#  'OR6C4',
#  'MESTIT1',
#  'BARHL2',
#  'BX005040.1',
#  'LINC02279',
#  'AC023796.2',
#  'MIR4307HG',
#  'AC019257.1',
#  'AC116348.1',
#  'CCL16',
#  'AL691497.1',
#  'AC025252.1',
#  'EGFLAM-AS4',
#  'AC016644.1',
#  'KCNIP4-IT1',
#  'UGT1A6',
#  'LINC01779',
#  'FUT5',
#  'AL450313.1',
#  'AC092335.1',
#  'AC018692.1',
#  'GOLGA8G',
#  'CBLN1',
#  'AHSP',
#  'AC098848.1',
#  'AC096669.1',
#  'AC024132.2',
#  'AC074366.1',
#  'AC011195.2',
#  'AC010255.2',
#  'AC113145.1',
#  'AC139749.1',
#  'ACSM1',
#  'AC027309.1',
#  'AC001226.1',
#  'OR52B6',
#  'LINC02183',
#  'AC009884.1',
#  'GOLGA6L22',
#  'MBD3L5',
#  'AC118755.2',
#  'PRAMEF2',
#  'AC074052.2',
#  'LINC01728',
#  'AC025265.2',
#  'TRIM64B',
#  'CA7',
#  'LUZP4',
#  'NKX1-1',
#  'AC123768.1',
#  'LINC01795',
#  'AC114812.2',
#  'LINC01656',
#  'AC008073.1',
#  'AC091906.1',
#  'AL355990.2',
#  'IL13',
#  'L29074.1',
#  'AL354989.1',
#  'AC121338.1',
#  'IL2RG',
#  'LINC00599',
#  'ESX1',
#  'AC110813.1',
#  'AC091185.1',
#  'AC007406.3',
#  'FIGNL2',
#  'CT55',
#  'LINC02332',
#  'AP000790.4',
#  'IRX4',
#  'GPR87',
#  'EVPLL',
#  'MYADML2',
#  'AC025165.1',
#  'LINC02032',
#  'UGT2A3',
#  'SCNN1G',
#  'AC008073.2',
#  'AC040963.1',
#  'AC135782.1',
#  'NTSR2',
#  'C8orf49',
#  'DYDC1',
#  'AC092134.1',
#  'LINC02181',
#  'AL589986.1',
#  'LINC02358',
#  'ECEL1',
#  'AC007349.1',
#  'AC011524.2',
#  'TTC3-AS1',
#  'LINC02401',
#  'AL021877.2',
#  'DAOA-AS1',
#  'OR8J3',
#  'AL161782.1',
#  'AL353770.3',
#  'AL096678.1',
#  'AL139008.2',
#  'AL135960.1',
#  'AC108097.1',
#  'AC092447.4',
#  'HTR2A-AS1',
#  'AC009163.2',
#  'CCDC70',
#  'TMEM176A',
#  'CCL8',
#  'AC108063.1',
#  'AC233724.6',
#  'LINC01565',
#  'LHX1',
#  'AC002511.1',
#  'KRT33A',
#  'LINC01855',
#  'AC078814.1',
#  'AC145207.1',
#  'AP003715.1',
#  'DEFB104A',
#  'AC099487.1',
#  'AC027801.4',
#  'AC009498.1',
#  'AC025437.5',
#  'OR4E2',
#  'AC005520.1',
#  'AL079307.2',
#  'VSIG10L2',
#  'AC010319.4',
#  'MME-AS1',
#  'AP000786.1',
#  'TRAJ54',
#  'LINC01961',
#  'AC093326.1',
#  'AL354761.1',
#  'IGKV2-19',
#  'FAM83C',
#  'LINC01093',
#  'CXXC5-AS1',
#  'AL590483.2',
#  'AL645937.4',
#  'AC100868.1',
#  'AC003685.1',
#  'LINC01648',
#  'CYP4A22',
#  'CARD18',
#  'AC020915.5',
#  'FP325330.3',
#  'AL357033.4',
#  'GPRC5D',
#  'AC019155.2',
#  'CDX2',
#  'AL731575.1',
#  'AC003002.3',
#  'SRMS',
#  'SMR3A',
#  'AC103808.4',
#  'AP003680.1',
#  'LINC01425',
#  'AC123788.1',
#  'AC007952.5',
#  'TMEM72',
#  'CD300LG',
#  'AC010451.3',
#  'SPECC1L-ADORA2A',
#  'MID1IP1-AS1',
#  'APLNR',
#  'AC009411.1',
#  'AC022778.1',
#  'AC009336.2',
#  'MIA',
#  'AC068898.1',
#  'AC092447.5',
#  'LINC02312',
#  'RTP2',
#  'RNASEK-C17orf49',
#  'PDCD1',
#  'AP001092.1',
#  'MINDY4B',
#  'PRORY',
#  'SMAD1-AS2',
#  'EXOC3L4',
#  'LINC02404',
#  'AC233724.15',
#  'HIST2H3D',
#  'HOXB4',
#  'AC097375.2',
#  'LINC02499',
#  'AC116158.2',
#  'AC069155.1',
#  'LINC02047',
#  'TTTY3B',
#  'CU634019.2',
#  'OR6C2',
#  'SERPINB12',
#  'AL359815.1',
#  'LINC02314',
#  'HM13-AS1',
#  'CCDC194',
#  'SLC35G4',
#  'TCP10L2',
#  'BTNL9',
#  'OR1L1',
#  'AL954642.1',
#  'AP002768.1',
#  'AC133485.5',
#  'AL160408.5',
#  'AC104695.1',
#  'AL359881.1',
#  'NXNL1',
#  'AC016396.2',
#  'AC010157.1',
#  'AC018653.3',
#  'AC243547.3',
#  'AC073352.2',
#  'AC087286.2',
#  'LINC01595',
#  'AL445465.1',
#  'AC116348.2',
#  'AP006216.1',
#  'AC016229.1',
#  'HHATL-AS1',
#  'LINC02003',
#  'Z82198.1',
#  'AL158207.2',
#  'LINC00906',
#  'ZNF32-AS2',
#  'AC046158.1',
#  'AL451107.1',
#  'AL590422.1',
#  'AL121956.4',
#  'Z92544.1',
#  'AC027682.5',
#  'AP000640.1',
#  'AC012594.1',
#  'MS4A12',
#  'LINC02537',
#  'XAGE3',
#  'AC090425.1',
#  'AC024610.2',
#  'PROP1',
#  'LINC02124',
#  'LINC02347',
#  'ADAM30',
#  'LCE3A',
#  'AP003097.2',
#  'AC010185.1',
#  'AL033397.1',
#  'OR56B1',
#  'KCNA4',
#  'AC073133.2',
#  'ZNF878',
#  'KLK6',
#  'NMUR2',
#  'AL158834.1',
#  'AC006017.1',
#  'AC090772.3',
#  'LINC02195',
#  'FER1L6-AS1',
#  'AL162311.1',
#  'POTEB2',
#  'AL022323.1',
#  'AC007673.1',
#  'AC105935.1',
#  'AC093585.1',
#  'AC113410.2',
#  'MAGEA4-AS1',
#  'AC005197.1',
#  'LINC01065',
#  'LINC01861',
#  'AC067968.2',
#  'PIK3CG',
#  'LINC00412',
#  'UPK3A',
#  'LINC01043',
#  'AL354733.1',
#  'LINC01496',
#  'AC092611.1',
#  'LINC02418',
#  'LINC01912',
#  'AL807752.4',
#  'TMEM229A',
#  'FATE1',
#  'FAM224B',
#  'AC017002.2',
#  'AC020934.1',
#  ...}

# %%
len(symdiff)
# Out:
# 2266

# %% [markdown]
# # Loading barcodes
#
# Create a function to load barcode data from the dimension 2 file, mapping column IDs to cell barcodes.
#
# The file is simply a list of CBs, with each line corresponding to the same column in the count matrix.

# %%
def load_barcodes(batch, variant):
    result = []
    barcode_path = "source/{}.{}.cells.tsv".format(batch, variant)
    
    with open(barcode_path, "r") as barcodes:       
        for barcode in barcodes:
            barcode = barcode.strip()
            barcode += "-" + batch
            result.append(barcode)

    return result

# %% [markdown]
# All CBs should be unique.

# %%
cells_control = load_barcodes("control", "all")
assert len(cells_control) == len(set(cells_control))

# %%
cells_control = load_barcodes("treated", "all")
assert len(cells_control) == len(set(cells_control))

# %% [markdown]
# # Loading transcript count matrix
#
# The count matrix is of the format:
#
#     %
#     no_genes no_cells no_counts
#     19 1 1
#     34 1 1
#     [...]
#     33663 12318 1
#     33665 12318 35
#     33678 12318 1
#
# where the first number represents the gene, the second number represents the cell, and the third number represents the count.
#
# We then get a `cells` by `genes` count matrix indexed by the cell IDs and gene IDs as described above.

# %%
def load_transcript_matrix(batch, variant, genes, barcodes):
    matrix_path = "source/{}.{}.mm".format(batch, variant)
    
    matrix = None
    
    with open(matrix_path, "r") as f:
        first_line = True
        
        for line in f:
            if "%" in line:
                continue
            
            gene, cell, count = [int(i) for i in line.rstrip().split()]
            
            if first_line:
                assert gene == len(genes)
                assert cell == len(barcodes)
                
                first_line = False
                matrix = np.ndarray(shape=(cell, gene), dtype=np.dtype(np.int16))
                continue
            
            
            gene_pos = gene - 1
            cell_pos = cell - 1
            
            matrix[cell_pos, gene_pos] = count
    
    return matrix

# %% [markdown]
# # Create Pandas DataFrame from count matrix
#
# Given a count matrix of size `genes x cells`, a list of length `genes` and a list of length `cells`, create a Pandas DataFrame with index `cells` and column labels from `genes`.

# %%
def dataframe_from_matrix(m, genes, barcodes):
    assert m.shape == (len(barcodes), len(genes))
    
    # Create a data frame from the count matrix, keyed by the barcode
    # and gene annotations we created.
    result = pandas.DataFrame(m)
    result.index = barcodes
    result.columns = genes
    
    return result

# %% [markdown]
# # Construct DataFrame
#
# Given a batch identifier list (i.e. `["S1", "S2"]`) and matrix name list (i.e. `["exon", "intron"]`), create a Pandas DataFrame from the corresponding count matrices and gene/cell dimension file for each. In addition, update a set `genes_set` with all genes that have been encountered in this count matrix, as these are not normalized by default across matrices in a batch (unlike cell IDs).

# %%
def construct_dataframes(batches, matrices, genes_set):
    for batch_name in batches:    
        prev_barcodes = None

        for matrix_name in matrices:
            print("Now processing", batch_name, matrix_name)

            genes = load_genes(batch_name, matrix_name)        
            print("Genes list loaded at", len(genes), "items.")

            barcodes = load_barcodes(batch_name, matrix_name)
            print("Barcodes list loaded at", len(barcodes), "items.")

            print("Loading transcription matrix and converting to dataframe...")
            m = load_transcript_matrix(batch_name, matrix_name, genes, barcodes)
            m = dataframe_from_matrix(m, genes, barcodes)

            genes_set.update(m.columns)
            print("Total gene set is now", len(genes_set), "long.")

            if prev_barcodes is not None:
                assert m.index.equals(prev_barcodes)
            else:
                prev_barcodes = m.index
            

            m.to_pickle("/tmp/{}_{}.pickle".format(batch_name, matrix_name))
            print("Count matrix with dimensions", m.shape, "created and pickled for", batch_name, matrix_name)
            print("")

        print("")

# %% [markdown]
# # Sorting genes in DataFrames
#
# Given a batch identifier list (i.e. `["S1", "S2"]`) and matrix name list (i.e. `["exon", "intron"]`), load the corresponding DataFrames. Take the `genes_set` generated from the previous process and add to each dataframe the genes that are not encountered in that count matrix, and the counts to 0 for all cells. This is needed as all count matrices need to be the same dimension when the AnnData layers are generated. To normalize the list of genes, we will sort the columns alphabetically as well.

# %%
def normalize_dataframe_genes(batches, matrices, genes_set):
    print("Normalizing dimensions of count matrices along genes...")

    for batch_name in batches:    
        for matrix_name in matrices:
            m = pandas.read_pickle("/tmp/{}_{}.pickle".format(batch_name, matrix_name))

            print("Old shape of", batch_name, matrix_name, "was", m.shape)
            missing_genes = genes_set - set(m.columns)
            for missing_gene in missing_genes:
                m[missing_gene] = 0
            print("New shape is", m.shape)

            print("Reordering genes in alphabetical order...")
            print("Old column order was", m.columns)
            m = m.reindex(sorted(m.columns), axis=1)
            print("New column order is", m.columns)

            m.to_pickle("/tmp/{}_{}.pickle".format(batch_name, matrix_name))
            print("Normalized count matrix for", batch_name, matrix_name, "pickled.")
            print("")

        print("")

# %% [markdown]
# # Create layered AnnData object from batch matrices
#
# Create a layered AnnData object from frames for each individual batch. In practice, this takes all frames with names in a matrix list (i.e. `["intron", "exon", "spanning"]`) for each batch (i.e. `["S1", "S2"]`), and creates a layered AnnData object with layer names corresponding to `layer_names` (i.e. `["unspliced", "spliced", "ambiguous"]`) from these frames.
#
# Frames should have identical dimensions, indices and column names for this to work.
#
# The layer with name `all` is implicitly used as the main count matrix of the AnnData object.

# %%
def create_anndata_from_frames(batches, matrices, layer_names):
    results = []
    
    for batch in batches:
        result = None
        print("Now processing batch", batch, "...")
        
        for matrix, layer in zip(matrices, layer_names):
            print("Loading matrix", matrix, "...")
            m = pandas.read_pickle("/tmp/{}_{}.pickle".format(batch, matrix))
            
            if not result:
                print("Creating AnnData object...")
                
                result = anndata.AnnData(shape=m.shape)
                result.obs = pandas.DataFrame({"cellular_barcode": list(m.index)})
                result.var = pandas.DataFrame({"gene_names": list(m.columns)})
                
            if layer == "all":
                print("Layer is", layer, ", adding it as main count matrix to object...")
                result.X = m
            else:
                print("Adding count matrix as layer", layer, "to AnnData object...")
                result.layers[layer] = m.values
            
            print("")

        result.var_names = [gene for gene in result.var["gene_names"]]
        result.obs_names = [barcode for barcode in result.obs["cellular_barcode"]]
        result.obs_names_make_unique()
        results.append(result)
                
        print("Final AnnData object is", result)
        
        print("Saving layered AnnData object for batch", batch, "...")
        result.write("./write/{}-final.h5ad".format(batch))
        print("")

# %% [markdown]
# # Merge AnnData objects along batches
#
# Given a list of AnnData objects corresponding to each batch, create one large AnnData object comprising all batches. Save merged AnnData object for future processing.

# %%
def create_merged_anndata(batches):
    result = None
    to_merge = []
    
    for batch in batches:
        if not result:
            print("Merged AnnData file not yet created, making it from batch", batch)
            result = anndata.read_h5ad("./write/{}-final.h5ad".format(batch))
            print("Merged AnnData file is now", result)
        else:
            print("Loading batch", batch)
            curr = anndata.read_h5ad("./write/{}-final.h5ad".format(batch), backed="r+")
            print("Loaded AnnData file is", curr, ", appending to list of objects to concatenate...")
            to_merge.append(curr)
        print("")
    
    print("")        
    print("Concatenating list", to_merge, "to original file")
    result = result.concatenate(*to_merge, batch_categories=batches, index_unique=None)
    print("Concatenated AnnData object is", result, ", saving it to disk...")
    result.write("./write/merged-final.h5ad")

# %% [markdown]
# # Run the procedures above
# Create the variables for this experiment and run the procedures above, creating an AnnData matrix used in future notebooks.

# %%
batches = ('control', 'treated')
matrices = ('exon', 'intron', 'spanning', 'all')
layer_names = ('spliced', 'unspliced', 'ambiguous', 'all')
all_genes = set()

# %%
m = construct_dataframes(batches, matrices, all_genes)
# Out:
# Now processing control exon
# Genes list loaded at 22488 items.
# Barcodes list loaded at 12193 items.
# Loading transcription matrix and converting to dataframe...
# Total gene set is now 22488 long.
# Count matrix with dimensions (12193, 22488) created and pickled for control exon
#
# Now processing control intron
# Genes list loaded at 20030 items.
# Barcodes list loaded at 12193 items.
# Loading transcription matrix and converting to dataframe...
# Total gene set is now 26491 long.
# Count matrix with dimensions (12193, 20030) created and pickled for control intron
#
# Now processing control spanning
# Genes list loaded at 12977 items.
# Barcodes list loaded at 12193 items.
# Loading transcription matrix and converting to dataframe...
# Total gene set is now 26551 long.
# Count matrix with dimensions (12193, 12977) created and pickled for control spanning
#
# Now processing control all
# Genes list loaded at 26740 items.
# Barcodes list loaded at 12193 items.
# Loading transcription matrix and converting to dataframe...
# Total gene set is now 26740 long.
# Count matrix with dimensions (12193, 26740) created and pickled for control all
#
#
# Now processing treated exon
# Genes list loaded at 22184 items.
# Barcodes list loaded at 13183 items.
# Loading transcription matrix and converting to dataframe...
# Total gene set is now 27342 long.
# Count matrix with dimensions (13183, 22184) created and pickled for treated exon
#
# Now processing treated intron
# Genes list loaded at 19955 items.
# Barcodes list loaded at 13183 items.
# Loading transcription matrix and converting to dataframe...
# Total gene set is now 27682 long.
# Count matrix with dimensions (13183, 19955) created and pickled for treated intron
#
# Now processing treated spanning
# Genes list loaded at 12664 items.
# Barcodes list loaded at 13183 items.
# Loading transcription matrix and converting to dataframe...
# Total gene set is now 27705 long.
# Count matrix with dimensions (13183, 12664) created and pickled for treated spanning
#
# Now processing treated all
# Genes list loaded at 26590 items.
# Barcodes list loaded at 13183 items.
# Loading transcription matrix and converting to dataframe...
# Total gene set is now 27798 long.
# Count matrix with dimensions (13183, 26590) created and pickled for treated all

# %%
normalize_dataframe_genes(batches, matrices, all_genes)
# Out:
# Normalizing dimensions of count matrices along genes...
# Old shape of control exon was (12193, 22488)
# New shape is (12193, 27798)
# Reordering genes in alphabetical order...
# Old column order was Index(['WDR13', 'ZDHHC2', 'RPL10A', 'UCHL1', 'RPL13A', 'MICALL2', 'ISCU',
#        'TCP11L1', 'RPS18', 'MYL6',
#        ...
#        'AC011466.3', 'LINC00934', 'AL365204.2', 'AL035425.1', 'OR2G6',
#        'AL360014.1', 'LINC02135', 'AC007221.2', 'LILRA1', 'AC083800.1'],
#       dtype='object', length=27798)
# New column order is Index(['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', 'A2M-AS1', 'A2ML1', 'A2ML1-AS1',
#        'A4GALT', 'A4GNT', 'AAAS',
#        ...
#        'ZW10', 'ZWILCH', 'ZWINT', 'ZXDA', 'ZXDB', 'ZXDC', 'ZYG11A', 'ZYG11B',
#        'ZYX', 'ZZEF1'],
#       dtype='object', length=27798)
# Normalized count matrix for control exon pickled.
#
# Old shape of control intron was (12193, 20030)
# New shape is (12193, 27798)
# Reordering genes in alphabetical order...
# Old column order was Index(['PCAT1', 'STK3', 'EXOC4', 'CUX1', 'ARID1B', 'AHI1', 'NOXRED1', 'MTMR6',
#        'MKL1', 'TULP3',
#        ...
#        'NXPH3', 'AL121759.1', 'AC084871.2', 'DERL3', 'IER5', 'SLC35A3',
#        'AL365204.2', 'AP003170.4', 'LINC02135', 'AL121748.2'],
#       dtype='object', length=27798)
# New column order is Index(['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', 'A2M-AS1', 'A2ML1', 'A2ML1-AS1',
#        'A4GALT', 'A4GNT', 'AAAS',
#        ...
#        'ZW10', 'ZWILCH', 'ZWINT', 'ZXDA', 'ZXDB', 'ZXDC', 'ZYG11A', 'ZYG11B',
#        'ZYX', 'ZZEF1'],
#       dtype='object', length=27798)
# Normalized count matrix for control intron pickled.
#
# Old shape of control spanning was (12193, 12977)
# New shape is (12193, 27798)
# Reordering genes in alphabetical order...
# Old column order was Index(['ZNF586', 'POLR3C', 'COL12A1', 'NCOA7', 'CDC40', 'RPS3', 'RPL24',
#        'RPL18A', 'RPL39', 'NDUFB11',
#        ...
#        'FGFR2', 'SLC35A3', 'AC117402.1', 'KRT32', 'AL365204.2', 'AP003170.4',
#        'LINC02135', 'AL121748.2', 'AC104316.1', 'TRIM54'],
#       dtype='object', length=27798)
# New column order is Index(['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', 'A2M-AS1', 'A2ML1', 'A2ML1-AS1',
#        'A4GALT', 'A4GNT', 'AAAS',
#        ...
#        'ZW10', 'ZWILCH', 'ZWINT', 'ZXDA', 'ZXDB', 'ZXDC', 'ZYG11A', 'ZYG11B',
#        'ZYX', 'ZZEF1'],
#       dtype='object', length=27798)
# Normalized count matrix for control spanning pickled.
#
# Old shape of control all was (12193, 26740)
# New shape is (12193, 27798)
# Reordering genes in alphabetical order...
# Old column order was Index(['RPL10', 'DOCK11', 'MT-CO1', 'RPL7A', 'RPL7', 'ZDHHC2', 'CUX1',
#        'MICALL2', 'AHI1', 'TNIP1',
#        ...
#        'AC099328.2', 'AC118755.2', 'AC013269.2', 'AL365204.2', 'AC027018.1',
#        'AC020595.1', 'AC010680.3', 'LINC02135', 'GYG2-AS1', 'AC136475.8'],
#       dtype='object', length=27798)
# New column order is Index(['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', 'A2M-AS1', 'A2ML1', 'A2ML1-AS1',
#        'A4GALT', 'A4GNT', 'AAAS',
#        ...
#        'ZW10', 'ZWILCH', 'ZWINT', 'ZXDA', 'ZXDB', 'ZXDC', 'ZYG11A', 'ZYG11B',
#        'ZYX', 'ZZEF1'],
#       dtype='object', length=27798)
# Normalized count matrix for control all pickled.
#
#
# Old shape of treated exon was (13183, 22184)
# New shape is (13183, 27798)
# Reordering genes in alphabetical order...
# Old column order was Index(['RPL10', 'MT-CYB', 'MT-CO2', 'MT-CO1', 'CTSL', 'UHRF2', 'PABPC1',
#        'RPL7', 'SERPINE1', 'COL1A2',
#        ...
#        'MUC21', 'SLC22A10', 'AC074237.1', 'AC012103.1', 'LINC01817', 'HTR2C',
#        'AL589182.1', 'AP003170.4', 'AL121748.2', 'AC083800.1'],
#       dtype='object', length=27798)
# New column order is Index(['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', 'A2M-AS1', 'A2ML1', 'A2ML1-AS1',
#        'A4GALT', 'A4GNT', 'AAAS',
#        ...
#        'ZW10', 'ZWILCH', 'ZWINT', 'ZXDA', 'ZXDB', 'ZXDC', 'ZYG11A', 'ZYG11B',
#        'ZYX', 'ZZEF1'],
#       dtype='object', length=27798)
# Normalized count matrix for treated exon pickled.
#
# Old shape of treated intron was (13183, 19955)
# New shape is (13183, 27798)
# Reordering genes in alphabetical order...
# Old column order was Index(['RALA', 'TMEM219', 'SUGCT', 'ZNF609', 'CEP164', 'TDRD3', 'TPST1',
#        'PDGFC', 'MDN1', 'AC016708.1',
#        ...
#        'SSTR1', 'AC084871.2', 'DERL3', 'IER5', 'SLC35A3', 'AC092919.1',
#        'AL365204.2', 'AP003170.4', 'LINC02135', 'AL121748.2'],
#       dtype='object', length=27798)
# New column order is Index(['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', 'A2M-AS1', 'A2ML1', 'A2ML1-AS1',
#        'A4GALT', 'A4GNT', 'AAAS',
#        ...
#        'ZW10', 'ZWILCH', 'ZWINT', 'ZXDA', 'ZXDB', 'ZXDC', 'ZYG11A', 'ZYG11B',
#        'ZYX', 'ZZEF1'],
#       dtype='object', length=27798)
# Normalized count matrix for treated intron pickled.
#
# Old shape of treated spanning was (13183, 12664)
# New shape is (13183, 27798)
# Reordering genes in alphabetical order...
# Old column order was Index(['RPL12', 'RPS6', 'ALG5', 'SNHG7', 'RPS12', 'RPS14', 'ARHGAP29', 'PRDX5',
#        'TPM2', 'IGFBP7',
#        ...
#        'SFXN2', 'SLC35A3', 'AC117402.1', 'KRT32', 'AL365204.2', 'AP003170.4',
#        'LINC02135', 'AL121748.2', 'AC104316.1', 'TRIM54'],
#       dtype='object', length=27798)
# New column order is Index(['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', 'A2M-AS1', 'A2ML1', 'A2ML1-AS1',
#        'A4GALT', 'A4GNT', 'AAAS',
#        ...
#        'ZW10', 'ZWILCH', 'ZWINT', 'ZXDA', 'ZXDB', 'ZXDC', 'ZYG11A', 'ZYG11B',
#        'ZYX', 'ZZEF1'],
#       dtype='object', length=27798)
# Normalized count matrix for treated spanning pickled.
#
# Old shape of treated all was (13183, 26590)
# New shape is (13183, 27798)
# Reordering genes in alphabetical order...
# Old column order was Index(['RPL10', 'MT-CYB', 'MT-CO2', 'MT-CO1', 'CTSL', 'UHRF2', 'PABPC1',
#        'RPL7', 'SERPINE1', 'GNG11',
#        ...
#        'TRIM10', 'IVL', 'AL031186.1', 'AC239802.1', 'AC131649.1', 'AL035425.1',
#        'AP003170.4', 'AL121748.2', 'SLC7A3', 'AC027808.2'],
#       dtype='object', length=27798)
# New column order is Index(['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', 'A2M-AS1', 'A2ML1', 'A2ML1-AS1',
#        'A4GALT', 'A4GNT', 'AAAS',
#        ...
#        'ZW10', 'ZWILCH', 'ZWINT', 'ZXDA', 'ZXDB', 'ZXDC', 'ZYG11A', 'ZYG11B',
#        'ZYX', 'ZZEF1'],
#       dtype='object', length=27798)
# Normalized count matrix for treated all pickled.

# %%
create_anndata_from_frames(batches, matrices, layer_names)
# Out:
# Now processing batch control ...
# Loading matrix exon ...
# AnnData expects string indices for some functionality, but your first two indices are: RangeIndex(start=0, stop=2, step=1).
# AnnData expects string indices for some functionality, but your first two indices are: RangeIndex(start=0, stop=2, step=1).
# Creating AnnData object...
# Adding count matrix as layer spliced to AnnData object...
#
# Loading matrix intron ...
# Adding count matrix as layer unspliced to AnnData object...
#
# Loading matrix spanning ...
# Adding count matrix as layer ambiguous to AnnData object...
#
# Loading matrix all ...
# Layer is all , adding it as main count matrix to object...
#
# Final AnnData object is AnnData object with n_obs × n_vars = 12193 × 27798
#     obs: 'cellular_barcode'
#     var: 'gene_names'
#     layers: 'spliced', 'unspliced', 'ambiguous'
# Saving layered AnnData object for batch control ...
#
# Now processing batch treated ...
# Loading matrix exon ...
# AnnData expects string indices for some functionality, but your first two indices are: RangeIndex(start=0, stop=2, step=1).
# AnnData expects string indices for some functionality, but your first two indices are: RangeIndex(start=0, stop=2, step=1).
# Creating AnnData object...
# Adding count matrix as layer spliced to AnnData object...
#
# Loading matrix intron ...
# Adding count matrix as layer unspliced to AnnData object...
#
# Loading matrix spanning ...
# Adding count matrix as layer ambiguous to AnnData object...
#
# Loading matrix all ...
# Layer is all , adding it as main count matrix to object...
#
# Final AnnData object is AnnData object with n_obs × n_vars = 13183 × 27798
#     obs: 'cellular_barcode'
#     var: 'gene_names'
#     layers: 'spliced', 'unspliced', 'ambiguous'
# Saving layered AnnData object for batch treated ...

# %%
create_merged_anndata(batches)
# Out:
# Merged AnnData file not yet created, making it from batch control
# Merged AnnData file is now AnnData object with n_obs × n_vars = 12193 × 27798
#     obs: 'cellular_barcode'
#     var: 'gene_names'
#     layers: 'ambiguous', 'spliced', 'unspliced'
#
# Loading batch treated
# Loaded AnnData file is AnnData object with n_obs × n_vars = 13183 × 27798 backed at 'write/treated-final.h5ad'
#     obs: 'cellular_barcode'
#     var: 'gene_names'
#     layers: 'ambiguous', 'spliced', 'unspliced' , appending to list of objects to concatenate...
#
#
# Concatenating list [AnnData object with n_obs × n_vars = 13183 × 27798 backed at 'write/treated-final.h5ad'
#     obs: 'cellular_barcode'
#     var: 'gene_names'
#     layers: 'ambiguous', 'spliced', 'unspliced'] to original file
# Concatenated AnnData object is AnnData object with n_obs × n_vars = 25376 × 27798
#     obs: 'batch', 'cellular_barcode'
#     var: 'gene_names-control', 'gene_names-treated'
#     layers: 'ambiguous', 'spliced', 'unspliced' , saving it to disk...
